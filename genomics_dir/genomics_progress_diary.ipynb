# %% [markdown]
# # Genomics vs Standard - Progress diary

# %% [markdown]
# ### June 2026

# %% [markdown]
# #### 30Jun26

# %% [markdown]
# ##### Landmark-matched post-personalization case-control trajectory analysis - finding best matching parameters

# %% [markdown]
# ###### Search grid used:

# %% [markdown]
# MATCHING_PARAM_OPTIONS = {
#     "landmark_window_days": [10],
#     "caliper_sd": [0.10, 0.15, 0.20],
#     "landmark_weight_caliper_kg": [0.5, 1.0, 1.5],
#     "slope_caliper_kg_per_day": [0.03, 0.05, 0.10],
#     "weight_ps_distance": [1.0],
#     "weight_landmark_weight_distance": [1.0],
#     "weight_slope_distance": [1.0],
# }

# %% [markdown]
# ###### Top 10 combinations:

# %% [markdown]
# ================================================================================-
#  TOP GRID SEARCH RESULTS
# ================================================================================-
#
#  run_id  landmark_window_days  caliper_sd  landmark_weight_caliper_kg  slope_caliper_kg_per_day  weight_ps_distance  weight_landmark_weight_distance  weight_slope_distance  n_pairs  match_rate  mean_abs_smd  max_abs_smd  mean_abs_weight_dist  mean_abs_slope_dist  total_rank
#      24                    10        0.20                         1.0                      0.10                 1.0                              1.0                    1.0      883      0.9577        0.0283       0.0564                0.5178               0.0453        44.0
#      26                    10        0.20                         1.5                      0.05                 1.0                              1.0                    1.0      879      0.9534        0.0275       0.0571                0.8048               0.0242        45.0
#      17                    10        0.15                         1.5                      0.05                 1.0                              1.0                    1.0      869      0.9425        0.0282       0.0551                0.8049               0.0242        48.0
#       6                    10        0.10                         1.0                      0.10                 1.0                              1.0                    1.0      858      0.9306        0.0282       0.0555                0.5181               0.0452        50.0
#      15                    10        0.15                         1.0                      0.10                 1.0                              1.0                    1.0      874      0.9479        0.0289       0.0601                0.5184               0.0452        51.0
#      23                    10        0.20                         1.0                      0.05                 1.0                              1.0                    1.0      863      0.9360        0.0315       0.0733                0.5388               0.0240        55.0
#      27                    10        0.20                         1.5                      0.10                 1.0                              1.0                    1.0      894      0.9696        0.0310       0.0642                0.7833               0.0446        58.0
#      18                    10        0.15                         1.5                      0.10                 1.0                              1.0                    1.0      890      0.9653        0.0304       0.0647                0.7829               0.0446        60.0
#      21                    10        0.20                         0.5                      0.10                 1.0                              1.0                    1.0      859      0.9317        0.0288       0.0736                0.2747               0.0479        61.0
#      25                    10        0.20                         1.5                      0.03                 1.0                              1.0                    1.0      862      0.9349        0.0325       0.0733                0.8078               0.0146        65.0
#
# ================================================================================--

# %% [markdown]
# ###### Mathcing performance of each combination:

# %% [markdown]
# ================================================================================-
#  LOAD SOURCE TABLES
# ================================================================================-
#
# Treated records: 962 | Control records: 11128 | Measurement rows: 395415
#
# ================================================================================-
#  APPLY TREATED LANDMARK INCLUSION RULE
# ================================================================================-
#
# Treated retained after landmark filter: 922 / 962
#
# ================================================================================-
#  MATCHING GRID SEARCH
# ================================================================================-
#
#
# ================================================================================-
#  GRID RUN 1 / 27
# ================================================================================-
#
# {'landmark_window_days': 10, 'caliper_sd': 0.1, 'landmark_weight_caliper_kg': 0.5, 'slope_caliper_kg_per_day': 0.03, 'weight_ps_distance': 1.0, 'weight_landmark_weight_distance': 1.0, 'weight_slope_distance': 1.0}
#
# ================================================================================-
#  GLOBAL 1:1 MATCHING WITH LANDMARK WEIGHT + PRE-LANDMARK SLOPE
# ================================================================================-
#
#
# ================================================================================-
#  GLOBAL 1:1 MATCHING WITH LANDMARK WEIGHT + PRE-LANDMARK SLOPE
# ================================================================================-
#
# C:\Users\miksa.henkrich\AppData\Local\Temp\ipykernel_1396\837112860.py:800: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   pooled_df = pd.concat(
# Logit-PS Caliper: 0.0333 | Absolute Weight Caliper: 0.5 kg
# Records entering matching -> Treated: 922 | Controls: 11128
# C:\Users\miksa.henkrich\AppData\Local\Temp\ipykernel_1396\837112860.py:1059: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   matched_analysis_df = pd.concat(
# Matched pairs: 710 (Rate: 0.770)
# Mean abs landmark weight diff: 0.273 kg
# Mean abs pre-landmark slope diff: 0.0156 kg/day
#
# ================================================================================-
#  GRID RUN 2 / 27
# ================================================================================-
#
# {'landmark_window_days': 10, 'caliper_sd': 0.1, 'landmark_weight_caliper_kg': 0.5, 'slope_caliper_kg_per_day': 0.05, 'weight_ps_distance': 1.0, 'weight_landmark_weight_distance': 1.0, 'weight_slope_distance': 1.0}
#
# ================================================================================-
#  GLOBAL 1:1 MATCHING WITH LANDMARK WEIGHT + PRE-LANDMARK SLOPE
# ================================================================================-
#
#
# ================================================================================-
#  GLOBAL 1:1 MATCHING WITH LANDMARK WEIGHT + PRE-LANDMARK SLOPE
# ================================================================================-
#
# C:\Users\miksa.henkrich\AppData\Local\Temp\ipykernel_1396\837112860.py:800: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   pooled_df = pd.concat(
# Logit-PS Caliper: 0.0333 | Absolute Weight Caliper: 0.5 kg
# Records entering matching -> Treated: 922 | Controls: 11128
# C:\Users\miksa.henkrich\AppData\Local\Temp\ipykernel_1396\837112860.py:1059: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   matched_analysis_df = pd.concat(
# C:\Users\miksa.henkrich\AppData\Local\Temp\ipykernel_1396\837112860.py:800: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   pooled_df = pd.concat(
# Matched pairs: 773 (Rate: 0.838)
# Mean abs landmark weight diff: 0.274 kg
# Mean abs pre-landmark slope diff: 0.0258 kg/day
#
# ================================================================================-
#  GRID RUN 3 / 27
# ================================================================================-
#
# {'landmark_window_days': 10, 'caliper_sd': 0.1, 'landmark_weight_caliper_kg': 0.5, 'slope_caliper_kg_per_day': 0.1, 'weight_ps_distance': 1.0, 'weight_landmark_weight_distance': 1.0, 'weight_slope_distance': 1.0}
#
# ================================================================================-
#  GLOBAL 1:1 MATCHING WITH LANDMARK WEIGHT + PRE-LANDMARK SLOPE
# ================================================================================-
#
#
# ================================================================================-
#  GLOBAL 1:1 MATCHING WITH LANDMARK WEIGHT + PRE-LANDMARK SLOPE
# ================================================================================-
# -
# Logit-PS Caliper: 0.0333 | Absolute Weight Caliper: 0.5 kg
# Records entering matching -> Treated: 922 | Controls: 11128
# C:\Users\miksa.henkrich\AppData\Local\Temp\ipykernel_1396\837112860.py:1059: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   matched_analysis_df = pd.concat(
# C:\Users\miksa.henkrich\AppData\Local\Temp\ipykernel_1396\837112860.py:800: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   pooled_df = pd.concat(
# Matched pairs: 829 (Rate: 0.899)
# Mean abs landmark weight diff: 0.277 kg
# Mean abs pre-landmark slope diff: 0.0479 kg/day
#
# ================================================================================-
#  GRID RUN 4 / 27
# ================================================================================-
#
# {'landmark_window_days': 10, 'caliper_sd': 0.1, 'landmark_weight_caliper_kg': 1.0, 'slope_caliper_kg_per_day': 0.03, 'weight_ps_distance': 1.0, 'weight_landmark_weight_distance': 1.0, 'weight_slope_distance': 1.0}
#
# ================================================================================-
#  GLOBAL 1:1 MATCHING WITH LANDMARK WEIGHT + PRE-LANDMARK SLOPE
# ================================================================================-
#
#
# ================================================================================-
#  GLOBAL 1:1 MATCHING WITH LANDMARK WEIGHT + PRE-LANDMARK SLOPE
# ================================================================================-
#
# Logit-PS Caliper: 0.0333 | Absolute Weight Caliper: 1.0 kg
# Records entering matching -> Treated: 922 | Controls: 11128
# C:\Users\miksa.henkrich\AppData\Local\Temp\ipykernel_1396\837112860.py:1059: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   matched_analysis_df = pd.concat(
# C:\Users\miksa.henkrich\AppData\Local\Temp\ipykernel_1396\837112860.py:800: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   pooled_df = pd.concat(
# Matched pairs: 794 (Rate: 0.861)
# Mean abs landmark weight diff: 0.557 kg
# Mean abs pre-landmark slope diff: 0.0146 kg/day
#
# ================================================================================-
#  GRID RUN 5 / 27
# ================================================================================-
#
# {'landmark_window_days': 10, 'caliper_sd': 0.1, 'landmark_weight_caliper_kg': 1.0, 'slope_caliper_kg_per_day': 0.05, 'weight_ps_distance': 1.0, 'weight_landmark_weight_distance': 1.0, 'weight_slope_distance': 1.0}
# -
# ================================================================================-
#  GLOBAL 1:1 MATCHING WITH LANDMARK WEIGHT + PRE-LANDMARK SLOPE
# ================================================================================-
#
#
# ================================================================================-
#  GLOBAL 1:1 MATCHING WITH LANDMARK WEIGHT + PRE-LANDMARK SLOPE
# ================================================================================-
#
# Logit-PS Caliper: 0.0333 | Absolute Weight Caliper: 1.0 kg
# Records entering matching -> Treated: 922 | Controls: 11128
# C:\Users\miksa.henkrich\AppData\Local\Temp\ipykernel_1396\837112860.py:1059: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   matched_analysis_df = pd.concat(
# Matched pairs: 831 (Rate: 0.901)
# Mean abs landmark weight diff: 0.541 kg
# Mean abs pre-landmark slope diff: 0.0241 kg/day
#
# ================================================================================-
#  GRID RUN 6 / 27
# ================================================================================-
#
# {'landmark_window_days': 10, 'caliper_sd': 0.1, 'landmark_weight_caliper_kg': 1.0, 'slope_caliper_kg_per_day': 0.1, 'weight_ps_distance': 1.0, 'weight_landmark_weight_distance': 1.0, 'weight_slope_distance': 1.0}
#
# ================================================================================-
#  GLOBAL 1:1 MATCHING WITH LANDMARK WEIGHT + PRE-LANDMARK SLOPE
# ================================================================================-
#
#
# ================================================================================-
#  GLOBAL 1:1 MATCHING WITH LANDMARK WEIGHT + PRE-LANDMARK SLOPE
# ================================================================================-
#
# C:\Users\miksa.henkrich\AppData\Local\Temp\ipykernel_1396\837112860.py:800: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   pooled_df = pd.concat(
# Logit-PS Caliper: 0.0333 | Absolute Weight Caliper: 1.0 kg
# Records entering matching -> Treated: 922 | Controls: 11128
# C:\Users\miksa.henkrich\AppData\Local\Temp\ipykernel_1396\837112860.py:1059: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   matched_analysis_df = pd.concat(
# Matched pairs: 858 (Rate: 0.931)
# Mean abs landmark weight diff: 0.518 kg
# Mean abs pre-landmark slope diff: 0.0452 kg/day
#
# ================================================================================-
#  GRID RUN 7 / 27
# ================================================================================-
#
# {'landmark_window_days': 10, 'caliper_sd': 0.1, 'landmark_weight_caliper_kg': 1.5, 'slope_caliper_kg_per_day': 0.03, 'weight_ps_distance': 1.0, 'weight_landmark_weight_distance': 1.0, 'weight_slope_distance': 1.0}
#
# ================================================================================-
#  GLOBAL 1:1 MATCHING WITH LANDMARK WEIGHT + PRE-LANDMARK SLOPE
# ================================================================================-
#
#
# ================================================================================-
#  GLOBAL 1:1 MATCHING WITH LANDMARK WEIGHT + PRE-LANDMARK SLOPE
# ================================================================================-
#
# C:\Users\miksa.henkrich\AppData\Local\Temp\ipykernel_1396\837112860.py:800: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   pooled_df = pd.concat(
# Logit-PS Caliper: 0.0333 | Absolute Weight Caliper: 1.5 kg
# Records entering matching -> Treated: 922 | Controls: 11128
# C:\Users\miksa.henkrich\AppData\Local\Temp\ipykernel_1396\837112860.py:1059: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   matched_analysis_df = pd.concat(
# C:\Users\miksa.henkrich\AppData\Local\Temp\ipykernel_1396\837112860.py:800: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   pooled_df = pd.concat(
# Matched pairs: 823 (Rate: 0.893)
# Mean abs landmark weight diff: 0.812 kg
# Mean abs pre-landmark slope diff: 0.0145 kg/day
#
# ================================================================================-
#  GRID RUN 8 / 27
# ================================================================================-
#
# {'landmark_window_days': 10, 'caliper_sd': 0.1, 'landmark_weight_caliper_kg': 1.5, 'slope_caliper_kg_per_day': 0.05, 'weight_ps_distance': 1.0, 'weight_landmark_weight_distance': 1.0, 'weight_slope_distance': 1.0}
#
# ================================================================================-
#  GLOBAL 1:1 MATCHING WITH LANDMARK WEIGHT + PRE-LANDMARK SLOPE
# ================================================================================-
#
#
# ================================================================================-
#  GLOBAL 1:1 MATCHING WITH LANDMARK WEIGHT + PRE-LANDMARK SLOPE
# ================================================================================-
#
# Logit-PS Caliper: 0.0333 | Absolute Weight Caliper: 1.5 kg
# Records entering matching -> Treated: 922 | Controls: 11128
# C:\Users\miksa.henkrich\AppData\Local\Temp\ipykernel_1396\837112860.py:1059: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   matched_analysis_df = pd.concat(
# C:\Users\miksa.henkrich\AppData\Local\Temp\ipykernel_1396\837112860.py:800: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   pooled_df = pd.concat(
# Matched pairs: 854 (Rate: 0.926)
# Mean abs landmark weight diff: 0.806 kg
# Mean abs pre-landmark slope diff: 0.0242 kg/day
#
# ================================================================================-
#  GRID RUN 9 / 27
# ================================================================================-
#
# {'landmark_window_days': 10, 'caliper_sd': 0.1, 'landmark_weight_caliper_kg': 1.5, 'slope_caliper_kg_per_day': 0.1, 'weight_ps_distance': 1.0, 'weight_landmark_weight_distance': 1.0, 'weight_slope_distance': 1.0}
#
# ================================================================================-
#  GLOBAL 1:1 MATCHING WITH LANDMARK WEIGHT + PRE-LANDMARK SLOPE
# ================================================================================-
#
#
# ================================================================================-
#  GLOBAL 1:1 MATCHING WITH LANDMARK WEIGHT + PRE-LANDMARK SLOPE
# ================================================================================-
#
# Logit-PS Caliper: 0.0333 | Absolute Weight Caliper: 1.5 kg
# Records entering matching -> Treated: 922 | Controls: 11128
# C:\Users\miksa.henkrich\AppData\Local\Temp\ipykernel_1396\837112860.py:1059: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   matched_analysis_df = pd.concat(
# C:\Users\miksa.henkrich\AppData\Local\Temp\ipykernel_1396\837112860.py:800: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   pooled_df = pd.concat(
# Matched pairs: 875 (Rate: 0.949)
# Mean abs landmark weight diff: 0.781 kg
# Mean abs pre-landmark slope diff: 0.0447 kg/day
#
# ================================================================================-
#  GRID RUN 10 / 27
# ================================================================================-
#
# {'landmark_window_days': 10, 'caliper_sd': 0.15, 'landmark_weight_caliper_kg': 0.5, 'slope_caliper_kg_per_day': 0.03, 'weight_ps_distance': 1.0, 'weight_landmark_weight_distance': 1.0, 'weight_slope_distance': 1.0}
#
# ================================================================================-
#  GLOBAL 1:1 MATCHING WITH LANDMARK WEIGHT + PRE-LANDMARK SLOPE
# ================================================================================-
#
#
# ================================================================================-
#  GLOBAL 1:1 MATCHING WITH LANDMARK WEIGHT + PRE-LANDMARK SLOPE
# ================================================================================-
#
# Logit-PS Caliper: 0.0500 | Absolute Weight Caliper: 0.5 kg
# Records entering matching -> Treated: 922 | Controls: 11128
# C:\Users\miksa.henkrich\AppData\Local\Temp\ipykernel_1396\837112860.py:1059: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   matched_analysis_df = pd.concat(
# C:\Users\miksa.henkrich\AppData\Local\Temp\ipykernel_1396\837112860.py:800: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   pooled_df = pd.concat(
# Matched pairs: 754 (Rate: 0.818)
# Mean abs landmark weight diff: 0.271 kg
# Mean abs pre-landmark slope diff: 0.0155 kg/day
#
# ================================================================================-
#  GRID RUN 11 / 27
# ================================================================================-
#
# {'landmark_window_days': 10, 'caliper_sd': 0.15, 'landmark_weight_caliper_kg': 0.5, 'slope_caliper_kg_per_day': 0.05, 'weight_ps_distance': 1.0, 'weight_landmark_weight_distance': 1.0, 'weight_slope_distance': 1.0}
#
# ======================================================================-==========
#  GLOBAL 1:1 MATCHING WITH LANDMARK WEIGHT + PRE-LANDMARK SLOPE
# ================================================================================-
#
#
# ========================================================================-========
#  GLOBAL 1:1 MATCHING WITH LANDMARK WEIGHT + PRE-LANDMARK SLOPE
# ========================================================================--========
#
# Logit-PS Caliper: 0.0500 | Absolute Weight Caliper: 0.5 kg
# Records entering matching -> Treated: 922 | Controls: 11128
# C:\Users\miksa.henkrich\AppData\Local\Temp\ipykernel_1396\837112860.py:1059: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   matched_analysis_df = pd.concat(
# C:\Users\miksa.henkrich\AppData\Local\Temp\ipykernel_1396\837112860.py:800: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   pooled_df = pd.concat(
# Matched pairs: 806 (Rate: 0.874)
# Mean abs landmark weight diff: 0.273 kg
# Mean abs pre-landmark slope diff: 0.0256 kg/day
#
# ==============================================================-==================
#  GRID RUN 12 / 27
# ===============================================================-=================
#
# {'landmark_window_days': 10, 'caliper_sd': 0.15, 'landmark_weight_caliper_kg': 0.5, 'slope_caliper_kg_per_day': 0.1, 'weight_ps_distance': 1.0, 'weight_landmark_weight_distance': 1.0, 'weight_slope_distance': 1.0}
#
# =======================================================================-=========
#  GLOBAL 1:1 MATCHING WITH LANDMARK WEIGHT + PRE-LANDMARK SLOPE
# ========================================================================-========
#
#
# =====================================================================-===========
#  GLOBAL 1:1 MATCHING WITH LANDMARK WEIGHT + PRE-LANDMARK SLOPE
# =====================================================================-===========
#
# Logit-PS Caliper: 0.0500 | Absolute Weight Caliper: 0.5 kg
# Records entering matching -> Treated: 922 | Controls: 11128
# C:\Users\miksa.henkrich\AppData\Local\Temp\ipykernel_1396\837112860.py:1059: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   matched_analysis_df = pd.concat(
# C:\Users\miksa.henkrich\AppData\Local\Temp\ipykernel_1396\837112860.py:800: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   pooled_df = pd.concat(
# Matched pairs: 849 (Rate: 0.921)
# Mean abs landmark weight diff: 0.275 kg
# Mean abs pre-landmark slope diff: 0.0478 kg/day
#
# ===========================================================-=====================
#  GRID RUN 13 / 27
# =========================================================-=======================
#
# {'landmark_window_days': 10, 'caliper_sd': 0.15, 'landmark_weight_caliper_kg': 1.0, 'slope_caliper_kg_per_day': 0.03, 'weight_ps_distance': 1.0, 'weight_landmark_weight_distance': 1.0, 'weight_slope_distance': 1.0}
#
# ==================================================================-==============
#  GLOBAL 1:1 MATCHING WITH LANDMARK WEIGHT + PRE-LANDMARK SLOPE
# =================================================================-===============
#
#
# ======================================================================-==========
#  GLOBAL 1:1 MATCHING WITH LANDMARK WEIGHT + PRE-LANDMARK SLOPE-
# ======================================================================-==========
#
# Logit-PS Caliper: 0.0500 | Absolute Weight Caliper: 1.0 kg
# Records entering matching -> Treated: 922 | Controls: 11128
# C:\Users\miksa.henkrich\AppData\Local\Temp\ipykernel_1396\837112860.py:1059: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   matched_analysis_df = pd.concat(
# C:\Users\miksa.henkrich\AppData\Local\Temp\ipykernel_1396\837112860.py:800: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   pooled_df = pd.concat(
# Matched pairs: 824 (Rate: 0.894)
# Mean abs landmark weight diff: 0.556 kg
# Mean abs pre-landmark slope diff: 0.0146 kg/day
#
# =================================================================-===============
#  GRID RUN 14 / 27
# ====================================================================-============
#
# {'landmark_window_days': 10, 'caliper_sd': 0.15, 'landmark_weight_caliper_kg': 1.0, 'slope_caliper_kg_per_day': 0.05, 'weight_ps_distance': 1.0, 'weight_landmark_weight_distance': 1.0, 'weight_slope_distance': 1.0}
#
# ======================================================================-==========
#  GLOBAL 1:1 MATCHING WITH LANDMARK WEIGHT + PRE-LANDMARK SLOPE
# =======================================================================-=========
#
#
# =====================================================================-===========
#  GLOBAL 1:1 MATCHING WITH LANDMARK WEIGHT + PRE-LANDMARK SLOPE
# ===================================================================-=============
#
# Logit-PS Caliper: 0.0500 | Absolute Weight Caliper: 1.0 kg
# Records entering matching -> Treated: 922 | Controls: 11128
# C:\Users\miksa.henkrich\AppData\Local\Temp\ipykernel_1396\837112860.py:1059: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   matched_analysis_df = pd.concat(
# C:\Users\miksa.henkrich\AppData\Local\Temp\ipykernel_1396\837112860.py:800: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   pooled_df = pd.concat(
# Matched pairs: 851 (Rate: 0.923)
# Mean abs landmark weight diff: 0.539 kg
# Mean abs pre-landmark slope diff: 0.0241 kg/day
#
# ===================================================================-=============
#  GRID RUN 15 / 27
# ===================================================================-=============
#
# {'landmark_window_days': 10, 'caliper_sd': 0.15, 'landmark_weight_caliper_kg': 1.0, 'slope_caliper_kg_per_day': 0.1, 'weight_ps_distance': 1.0, 'weight_landmark_weight_distance': 1.0, 'weight_slope_distance': 1.0}
#
# ================================================================-================
#  GLOBAL 1:1 MATCHING WITH LANDMARK WEIGHT + PRE-LANDMARK SLOPE
# ================================================================-================
#
#
# ======================================================================-==========
#  GLOBAL 1:1 MATCHING WITH LANDMARK WEIGHT + PRE-LANDMARK SLOPE
# =====================================================================-===========
#
# Logit-PS Caliper: 0.0500 | Absolute Weight Caliper: 1.0 kg
# Records entering matching -> Treated: 922 | Controls: 11128
# C:\Users\miksa.henkrich\AppData\Local\Temp\ipykernel_1396\837112860.py:1059: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   matched_analysis_df = pd.concat(
# C:\Users\miksa.henkrich\AppData\Local\Temp\ipykernel_1396\837112860.py:800: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   pooled_df = pd.concat(
# Matched pairs: 874 (Rate: 0.948)
# Mean abs landmark weight diff: 0.518 kg
# Mean abs pre-landmark slope diff: 0.0452 kg/day
#
# ============================================================-====================
#  GRID RUN 16 / 27
# ==========================================================-======================
#
# {'landmark_window_days': 10, 'caliper_sd': 0.15, 'landmark_weight_caliper_kg': 1.5, 'slope_caliper_kg_per_day': 0.03, 'weight_ps_distance': 1.0, 'weight_landmark_weight_distance': 1.0, 'weight_slope_distance': 1.0}
#
# ======================================================================-==========
#  GLOBAL 1:1 MATCHING WITH LANDMARK WEIGHT + PRE-LANDMARK SLOPE
# ==================================================================-==============
#
#
# ================================================================-================
#  GLOBAL 1:1 MATCHING WITH LANDMARK WEIGHT + PRE-LANDMARK SLOPE
# ===============================================================-=================
#
# Logit-PS Caliper: 0.0500 | Absolute Weight Caliper: 1.5 kg
# Records entering matching -> Treated: 922 | Controls: 11128
# C:\Users\miksa.henkrich\AppData\Local\Temp\ipykernel_1396\837112860.py:1059: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   matched_analysis_df = pd.concat(
# C:\Users\miksa.henkrich\AppData\Local\Temp\ipykernel_1396\837112860.py:800: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   pooled_df = pd.concat(
# Matched pairs: 846 (Rate: 0.918)
# Mean abs landmark weight diff: 0.813 kg
# Mean abs pre-landmark slope diff: 0.0146 kg/day
#
# =====================================================-===========================
#  GRID RUN 17 / 27
# ====================================================-============================
#
# {'landmark_window_days': 10, 'caliper_sd': 0.15, 'landmark_weight_caliper_kg': 1.5, 'slope_caliper_kg_per_day': 0.05, 'weight_ps_distance': 1.0, 'weight_landmark_weight_distance': 1.0, 'weight_slope_distance': 1.0}
#
# ==================================================-=============================
#  GLOBAL 1:1 MATCHING WITH LANDMARK WEIGHT + PRE-LANDMARK SLOPE
# ==============================================-==================================
#
#
# ======================================l==========================================
#  GLOBAL 1:1 MATCHING WITH LANDMARK WEIGHT + PRE-LANDMARK SLOPE
# =====================================l===========================================
#
# Logit-PS Caliper: 0.0500 | Absolute Weight Caliper: 1.5 kg
# Records entering matching -> Treated: 922 | Controls: 11128
# C:\Users\miksa.henkrich\AppData\Local\Temp\ipykernel_1396\837112860.py:1059: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   matched_analysis_df = pd.concat(
# C:\Users\miksa.henkrich\AppData\Local\Temp\ipykernel_1396\837112860.py:800: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   pooled_df = pd.concat(
# Matched pairs: 869 (Rate: 0.943)
# Mean abs landmark weight diff: 0.805 kg
# Mean abs pre-landmark slope diff: 0.0242 kg/day
#
# ===================================l============================================
#  GRID RUN 18 / 27
# ================================l================================================
#
# {'landmark_window_days': 10, 'caliper_sd': 0.15, 'landmark_weight_caliper_kg': 1.5, 'slope_caliper_kg_per_day': 0.1, 'weight_ps_distance': 1.0, 'weight_landmark_weight_distance': 1.0, 'weight_slope_distance': 1.0}
#
#
#  GLOBAL 1:1 MATCHING WITH LANDMARK WEIGHT + PRE-LANDMARK SLOPE
#
#
#
#  GLOBAL 1:1 MATCHING WITH LANDMARK WEIGHT + PRE-LANDMARK SLOPE
#
#
# Logit-PS Caliper: 0.0500 | Absolute Weight Caliper: 1.5 kg
# Records entering matching -> Treated: 922 | Controls: 11128
# C:\Users\miksa.henkrich\AppData\Local\Temp\ipykernel_1396\837112860.py:1059: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   matched_analysis_df = pd.concat(
# C:\Users\miksa.henkrich\AppData\Local\Temp\ipykernel_1396\837112860.py:800: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   pooled_df = pd.concat(
# Matched pairs: 890 (Rate: 0.965)
# Mean abs landmark weight diff: 0.783 kg
# Mean abs pre-landmark slope diff: 0.0446 kg/day
#
#
#  GRID RUN 19 / 27
#
#
# {'landmark_window_days': 10, 'caliper_sd': 0.2, 'landmark_weight_caliper_kg': 0.5, 'slope_caliper_kg_per_day': 0.03, 'weight_ps_distance': 1.0, 'weight_landmark_weight_distance': 1.0, 'weight_slope_distance': 1.0}
#
#
#  GLOBAL 1:1 MATCHING WITH LANDMARK WEIGHT + PRE-LANDMARK SLOPE
#
#
#
#
#  GLOBAL 1:1 MATCHING WITH LANDMARK WEIGHT + PRE-LANDMARK SLOPE
#
#
# Logit-PS Caliper: 0.0666 | Absolute Weight Caliper: 0.5 kg
# Records entering matching -> Treated: 922 | Controls: 11128
# C:\Users\miksa.henkrich\AppData\Local\Temp\ipykernel_1396\837112860.py:1059: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   matched_analysis_df = pd.concat(
# C:\Users\miksa.henkrich\AppData\Local\Temp\ipykernel_1396\837112860.py:800: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   pooled_df = pd.concat(
# Matched pairs: 788 (Rate: 0.855)
# Mean abs landmark weight diff: 0.270 kg
# Mean abs pre-landmark slope diff: 0.0156 kg/day
#
#
#  GRID RUN 20 / 27
#
#
# {'landmark_window_days': 10, 'caliper_sd': 0.2, 'landmark_weight_caliper_kg': 0.5, 'slope_caliper_kg_per_day': 0.05, 'weight_ps_distance': 1.0, 'weight_landmark_weight_distance': 1.0, 'weight_slope_distance': 1.0}
#
#
#  GLOBAL 1:1 MATCHING WITH LANDMARK WEIGHT + PRE-LANDMARK SLOPE
#
#
#
#
#  GLOBAL 1:1 MATCHING WITH LANDMARK WEIGHT + PRE-LANDMARK SLOPE
#
#
# Logit-PS Caliper: 0.0666 | Absolute Weight Caliper: 0.5 kg
# Records entering matching -> Treated: 922 | Controls: 11128
# C:\Users\miksa.henkrich\AppData\Local\Temp\ipykernel_1396\837112860.py:1059: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   matched_analysis_df = pd.concat(
# C:\Users\miksa.henkrich\AppData\Local\Temp\ipykernel_1396\837112860.py:800: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   pooled_df = pd.concat(
# Matched pairs: 825 (Rate: 0.895)
# Mean abs landmark weight diff: 0.273 kg
# Mean abs pre-landmark slope diff: 0.0254 kg/day
#
#
#  GRID RUN 21 / 27
#
#
# {'landmark_window_days': 10, 'caliper_sd': 0.2, 'landmark_weight_caliper_kg': 0.5, 'slope_caliper_kg_per_day': 0.1, 'weight_ps_distance': 1.0, 'weight_landmark_weight_distance': 1.0, 'weight_slope_distance': 1.0}
#
#
#  GLOBAL 1:1 MATCHING WITH LANDMARK WEIGHT + PRE-LANDMARK SLOPE
#
#
#
#
#  GLOBAL 1:1 MATCHING WITH LANDMARK WEIGHT + PRE-LANDMARK SLOPE
#
#
# Logit-PS Caliper: 0.0666 | Absolute Weight Caliper: 0.5 kg
# Records entering matching -> Treated: 922 | Controls: 11128
# C:\Users\miksa.henkrich\AppData\Local\Temp\ipykernel_1396\837112860.py:1059: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   matched_analysis_df = pd.concat(
# C:\Users\miksa.henkrich\AppData\Local\Temp\ipykernel_1396\837112860.py:800: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   pooled_df = pd.concat(
# Matched pairs: 859 (Rate: 0.932)
# Mean abs landmark weight diff: 0.275 kg
# Mean abs pre-landmark slope diff: 0.0479 kg/day
#
#
#  GRID RUN 22 / 27
#
#
# {'landmark_window_days': 10, 'caliper_sd': 0.2, 'landmark_weight_caliper_kg': 1.0, 'slope_caliper_kg_per_day': 0.03, 'weight_ps_distance': 1.0, 'weight_landmark_weight_distance': 1.0, 'weight_slope_distance': 1.0}
#
#
#  GLOBAL 1:1 MATCHING WITH LANDMARK WEIGHT + PRE-LANDMARK SLOPE
#
#
#
#
#  GLOBAL 1:1 MATCHING WITH LANDMARK WEIGHT + PRE-LANDMARK SLOPE
#
#
# Logit-PS Caliper: 0.0666 | Absolute Weight Caliper: 1.0 kg
# Records entering matching -> Treated: 922 | Controls: 11128
# C:\Users\miksa.henkrich\AppData\Local\Temp\ipykernel_1396\837112860.py:1059: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   matched_analysis_df = pd.concat(
# C:\Users\miksa.henkrich\AppData\Local\Temp\ipykernel_1396\837112860.py:800: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   pooled_df = pd.concat(
# Matched pairs: 841 (Rate: 0.912)
# Mean abs landmark weight diff: 0.552 kg
# Mean abs pre-landmark slope diff: 0.0146 kg/day
#
#
#  GRID RUN 23 / 27
#
#
# {'landmark_window_days': 10, 'caliper_sd': 0.2, 'landmark_weight_caliper_kg': 1.0, 'slope_caliper_kg_per_day': 0.05, 'weight_ps_distance': 1.0, 'weight_landmark_weight_distance': 1.0, 'weight_slope_distance': 1.0}
#
#
#  GLOBAL 1:1 MATCHING WITH LANDMARK WEIGHT + PRE-LANDMARK SLOPE
#
#
#
#
#  GLOBAL 1:1 MATCHING WITH LANDMARK WEIGHT + PRE-LANDMARK SLOPE
#
#
# Logit-PS Caliper: 0.0666 | Absolute Weight Caliper: 1.0 kg
# Records entering matching -> Treated: 922 | Controls: 11128
# C:\Users\miksa.henkrich\AppData\Local\Temp\ipykernel_1396\837112860.py:1059: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   matched_analysis_df = pd.concat(
# C:\Users\miksa.henkrich\AppData\Local\Temp\ipykernel_1396\837112860.py:800: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   pooled_df = pd.concat(
# Matched pairs: 863 (Rate: 0.936)
# Mean abs landmark weight diff: 0.539 kg
# Mean abs pre-landmark slope diff: 0.0240 kg/day
#
#
#  GRID RUN 24 / 27
#
#
# {'landmark_window_days': 10, 'caliper_sd': 0.2, 'landmark_weight_caliper_kg': 1.0, 'slope_caliper_kg_per_day': 0.1, 'weight_ps_distance': 1.0, 'weight_landmark_weight_distance': 1.0, 'weight_slope_distance': 1.0}
#
#
#  GLOBAL 1:1 MATCHING WITH LANDMARK WEIGHT + PRE-LANDMARK SLOPE
#
#
#
#
#  GLOBAL 1:1 MATCHING WITH LANDMARK WEIGHT + PRE-LANDMARK SLOPE
#
#
# Logit-PS Caliper: 0.0666 | Absolute Weight Caliper: 1.0 kg
# Records entering matching -> Treated: 922 | Controls: 11128
# C:\Users\miksa.henkrich\AppData\Local\Temp\ipykernel_1396\837112860.py:1059: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   matched_analysis_df = pd.concat(
# C:\Users\miksa.henkrich\AppData\Local\Temp\ipykernel_1396\837112860.py:800: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   pooled_df = pd.concat(
# Matched pairs: 883 (Rate: 0.958)
# Mean abs landmark weight diff: 0.518 kg
# Mean abs pre-landmark slope diff: 0.0453 kg/day
#
#
#  GRID RUN 25 / 27
#
#
# {'landmark_window_days': 10, 'caliper_sd': 0.2, 'landmark_weight_caliper_kg': 1.5, 'slope_caliper_kg_per_day': 0.03, 'weight_ps_distance': 1.0, 'weight_landmark_weight_distance': 1.0, 'weight_slope_distance': 1.0}
#
#
#  GLOBAL 1:1 MATCHING WITH LANDMARK WEIGHT + PRE-LANDMARK SLOPE
#
#
#
#
#  GLOBAL 1:1 MATCHING WITH LANDMARK WEIGHT + PRE-LANDMARK SLOPE
#
#
# Logit-PS Caliper: 0.0666 | Absolute Weight Caliper: 1.5 kg
# Records entering matching -> Treated: 922 | Controls: 11128
# C:\Users\miksa.henkrich\AppData\Local\Temp\ipykernel_1396\837112860.py:1059: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   matched_analysis_df = pd.concat(
# C:\Users\miksa.henkrich\AppData\Local\Temp\ipykernel_1396\837112860.py:800: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   pooled_df = pd.concat(
# Matched pairs: 862 (Rate: 0.935)
# Mean abs landmark weight diff: 0.808 kg
# Mean abs pre-landmark slope diff: 0.0146 kg/day
#
#
#  GRID RUN 26 / 27
#
#
# {'landmark_window_days': 10, 'caliper_sd': 0.2, 'landmark_weight_caliper_kg': 1.5, 'slope_caliper_kg_per_day': 0.05, 'weight_ps_distance': 1.0, 'weight_landmark_weight_distance': 1.0, 'weight_slope_distance': 1.0}
#
#
#  GLOBAL 1:1 MATCHING WITH LANDMARK WEIGHT + PRE-LANDMARK SLOPE
#
#
#
#
#  GLOBAL 1:1 MATCHING WITH LANDMARK WEIGHT + PRE-LANDMARK SLOPE
#
#
# Logit-PS Caliper: 0.0666 | Absolute Weight Caliper: 1.5 kg
# Records entering matching -> Treated: 922 | Controls: 11128
# C:\Users\miksa.henkrich\AppData\Local\Temp\ipykernel_1396\837112860.py:1059: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   matched_analysis_df = pd.concat(
# C:\Users\miksa.henkrich\AppData\Local\Temp\ipykernel_1396\837112860.py:800: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   pooled_df = pd.concat(
# Matched pairs: 879 (Rate: 0.953)
# Mean abs landmark weight diff: 0.805 kg
# Mean abs pre-landmark slope diff: 0.0242 kg/day
#
#
#  GRID RUN 27 / 27
#
#
# {'landmark_window_days': 10, 'caliper_sd': 0.2, 'landmark_weight_caliper_kg': 1.5, 'slope_caliper_kg_per_day': 0.1, 'weight_ps_distance': 1.0, 'weight_landmark_weight_distance': 1.0, 'weight_slope_distance': 1.0}
#
#
#  GLOBAL 1:1 MATCHING WITH LANDMARK WEIGHT + PRE-LANDMARK SLOPE
#
#
#
#
#  GLOBAL 1:1 MATCHING WITH LANDMARK WEIGHT + PRE-LANDMARK SLOPE
#
#
# Logit-PS Caliper: 0.0666 | Absolute Weight Caliper: 1.5 kg
# Records entering matching -> Treated: 922 | Controls: 11128
# C:\Users\miksa.henkrich\AppData\Local\Temp\ipykernel_1396\837112860.py:1059: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   matched_analysis_df = pd.concat(
# Matched pairs: 894 (Rate: 0.970)
# Mean abs landmark weight diff: 0.783 kg
# Mean abs pre-landmark slope diff: 0.0446 kg/day
#
#
#  GLOBAL 1:1 MATCHING WITH LANDMARK WEIGHT + PRE-LANDMARK SLOPE
#
#
#
#
#  GLOBAL 1:1 MATCHING WITH LANDMARK WEIGHT + PRE-LANDMARK SLOPE
#
#
# C:\Users\miksa.henkrich\AppData\Local\Temp\ipykernel_1396\837112860.py:800: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   pooled_df = pd.concat(
# Logit-PS Caliper: 0.0666 | Absolute Weight Caliper: 1.0 kg
# Records entering matching -> Treated: 922 | Controls: 11128
# C:\Users\miksa.henkrich\AppData\Local\Temp\ipykernel_1396\837112860.py:1059: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   matched_analysis_df = pd.concat(
# Matched pairs: 883 (Rate: 0.958)
# Mean abs landmark weight diff: 0.518 kg
# Mean abs pre-landmark slope diff: 0.0453 kg/day
#
#
#  BEST MATCHING PARAMETERS
#
#
# {'landmark_window_days': np.int64(10), 'caliper_sd': np.float64(0.2), 'landmark_weight_caliper_kg': np.float64(1.0), 'slope_caliper_kg_per_day': np.float64(0.1), 'weight_ps_distance': np.float64(1.0), 'weight_landmark_weight_distance': np.float64(1.0), 'weight_slope_distance': np.float64(1.0)}
#
#
#  TOP GRID SEARCH RESULTS
#
#
#  run_id  landmark_window_days  caliper_sd  landmark_weight_caliper_kg  slope_caliper_kg_per_day  weight_ps_distance  weight_landmark_weight_distance  weight_slope_distance  n_pairs  match_rate  mean_abs_smd  max_abs_smd  mean_abs_weight_dist  mean_abs_slope_dist  total_rank
#      24                    10        0.20                         1.0                      0.10                 1.0                              1.0                    1.0      883      0.9577        0.0283       0.0564                0.5178               0.0453        44.0
#      26                    10        0.20                         1.5                      0.05                 1.0                              1.0                    1.0      879      0.9534        0.0275       0.0571                0.8048               0.0242        45.0
#      17                    10        0.15                         1.5                      0.05                 1.0                              1.0                    1.0      869      0.9425        0.0282       0.0551                0.8049               0.0242        48.0
#       6                    10        0.10                         1.0                      0.10                 1.0                              1.0                    1.0      858      0.9306        0.0282       0.0555                0.5181               0.0452        50.0
#      15                    10        0.15                         1.0                      0.10                 1.0                              1.0                    1.0      874      0.9479        0.0289       0.0601                0.5184               0.0452        51.0
#      23                    10        0.20                         1.0                      0.05                 1.0                              1.0                    1.0      863      0.9360        0.0315       0.0733                0.5388               0.0240        55.0
#      27                    10        0.20                         1.5                      0.10                 1.0                              1.0                    1.0      894      0.9696        0.0310       0.0642                0.7833               0.0446        58.0
#      18                    10        0.15                         1.5                      0.10                 1.0                              1.0                    1.0      890      0.9653        0.0304       0.0647                0.7829               0.0446        60.0
#      21                    10        0.20                         0.5                      0.10                 1.0                              1.0                    1.0      859      0.9317        0.0288       0.0736                0.2747               0.0479        61.0
#      25                    10        0.20                         1.5                      0.03                 1.0                              1.0                    1.0      862      0.9349        0.0325       0.0733                0.8078               0.0146        65.0

# %% [markdown]
# ###### Summary of outcomes by the best match

# %% [markdown]
#  BEST MATCHING PARAMETERS
#
# {'landmark_window_days': np.int64(10), 'caliper_sd': np.float64(0.2), 'landmark_weight_caliper_kg': np.float64(1.0), 'slope_caliper_kg_per_day': np.float64(0.1), 'weight_ps_distance': np.float64(1.0), 'weight_landmark_weight_distance': np.float64(1.0), 'weight_slope_distance': np.float64(1.0)}
#
#
#  MATCHING DIAGNOSTICS
#
# --- Balance Before Matching ---
#           variable  treated_mean  control_mean    smd  abs_smd
#                age        47.848        46.372  0.142    0.142
#       baseline_bmi        31.564        30.923  0.154    0.154
# baseline_weight_kg        87.156        85.369  0.120    0.120
#         country_be         0.017         0.044 -0.155    0.155
#         country_ch         0.000         0.006 -0.107    0.107
#         country_es         0.709         0.747 -0.086    0.086
#         country_it         0.175         0.137  0.103    0.103
#         country_pt         0.099         0.066  0.121    0.121
# landmark_weight_kg        79.202           NaN    NaN      NaN
#              sex_f         0.777         0.790 -0.033    0.033
#
# --- Balance After Matching ---
#           variable  treated_mean  control_mean    smd  abs_smd
#                age        47.840        48.331 -0.049    0.049
#       baseline_bmi        31.389        31.429 -0.010    0.010
# baseline_weight_kg        86.472        86.139  0.025    0.025
#         country_be         0.014         0.012  0.010    0.010
#         country_ch         0.000         0.001 -0.048    0.048
#         country_es         0.718         0.733 -0.033    0.033
#         country_it         0.177         0.176  0.003    0.003
#         country_pt         0.092         0.078  0.049    0.049
# landmark_weight_kg        78.642        78.637  0.000    0.000
#              sex_f         0.787         0.810 -0.056    0.056
#
# --- Trajectory Matching Diagnostics ---
#                          variable  treated_mean  control_mean     smd  abs_smd
#     pre_landmark_slope_kg_per_day       -0.2236       -0.2197 -0.0325   0.0325
#           pairwise_abs_slope_dist           NaN           NaN     NaN   0.0453
# pairwise_abs_landmark_weight_dist           NaN           NaN     NaN   0.5178
#
#
#
#  STRATUM: Pooled
#
# Pairs: 883
#
# Stratum Balance:
#           variable  treated_mean  control_mean    smd  abs_smd
#                age        47.840        48.331 -0.049    0.049
#       baseline_bmi        31.389        31.429 -0.010    0.010
# baseline_weight_kg        86.472        86.139  0.025    0.025
#         country_be         0.014         0.012  0.010    0.010
#         country_ch         0.000         0.001 -0.048    0.048
#         country_es         0.718         0.733 -0.033    0.033
#         country_it         0.177         0.176  0.003    0.003
#         country_pt         0.092         0.078  0.049    0.049
# landmark_weight_kg        78.642        78.637  0.000    0.000
#              sex_f         0.787         0.810 -0.056    0.056
#
# Trajectory Matching Diagnostics:
#                          variable  treated_mean  control_mean     smd  abs_smd
#     pre_landmark_slope_kg_per_day       -0.2236       -0.2197 -0.0325   0.0325
#           pairwise_abs_slope_dist           NaN           NaN     NaN   0.0453
# pairwise_abs_landmark_weight_dist           NaN           NaN     NaN   0.5178
#
# Outcome Summary:
#                outcome  n_pairs  treated_mean  control_mean  diff_mean  wilcoxon_p
#  Final weight loss (%)      871         6.305         5.540      0.764       0.002
# Final weight loss (kg)      871         5.136         4.558      0.578       0.003
# 30-day weight loss (%)      528         3.846         3.743      0.103       0.642
# 60-day weight loss (%)      334         6.557         6.340      0.217       0.199
#
#
#  STRATUM: Early (≤30d)
#
#
# Pairs: 423
#
# Stratum Balance:
#           variable  treated_mean  control_mean    smd  abs_smd
#                age        48.066        47.582  0.048    0.048
#       baseline_bmi        31.326        31.176  0.039    0.039
# baseline_weight_kg        86.140        86.007  0.010    0.010
#         country_be         0.002         0.002  0.000    0.000
#         country_es         0.787         0.761  0.062    0.062
#         country_it         0.151         0.163 -0.032    0.032
#         country_pt         0.059         0.073 -0.057    0.057
# landmark_weight_kg        80.823        80.811  0.001    0.001
#              sex_f         0.792         0.799 -0.018    0.018
#
# Trajectory Matching Diagnostics:
#                          variable  treated_mean  control_mean    smd  abs_smd
#     pre_landmark_slope_kg_per_day       -0.2718       -0.2719 0.0007   0.0007
#           pairwise_abs_slope_dist           NaN           NaN    NaN   0.0472
# pairwise_abs_landmark_weight_dist           NaN           NaN    NaN   0.5175
#
# Outcome Summary:
#                outcome  n_pairs  treated_mean  control_mean  diff_mean  wilcoxon_p
#  Final weight loss (%)      423         7.855         6.781      1.075       0.004
# Final weight loss (kg)      423         6.510         5.695      0.816       0.005
# 30-day weight loss (%)      282         4.442         4.376      0.065       0.804
# 60-day weight loss (%)      173         7.777         7.409      0.368       0.238
#
#
#  STRATUM: Mid (30-60d)
#
#
# Pairs: 301
#
# Stratum Balance:
#           variable  treated_mean  control_mean    smd  abs_smd
#                age        47.110        48.960 -0.190    0.190
#       baseline_bmi        31.150        31.355 -0.051    0.051
# baseline_weight_kg        86.028        85.609  0.031    0.031
#         country_be         0.023         0.020  0.023    0.023
#         country_ch         0.000         0.003 -0.082    0.082
#         country_es         0.691         0.744 -0.118    0.118
#         country_it         0.173         0.176 -0.009    0.009
#         country_pt         0.113         0.056  0.204    0.204
# landmark_weight_kg        77.917        77.925 -0.001    0.001
#              sex_f         0.794         0.814 -0.050    0.050
#
# Trajectory Matching Diagnostics:
#                          variable  treated_mean  control_mean    smd  abs_smd
#     pre_landmark_slope_kg_per_day       -0.2027       -0.1935 -0.138   0.1380
#           pairwise_abs_slope_dist           NaN           NaN    NaN   0.0451
# pairwise_abs_landmark_weight_dist           NaN           NaN    NaN   0.5133
#
# Outcome Summary:
#                outcome  n_pairs  treated_mean  control_mean  diff_mean  wilcoxon_p
#  Final weight loss (%)      301         5.865         5.370      0.496       0.370
# Final weight loss (kg)      301         4.686         4.302      0.384       0.401
# 30-day weight loss (%)      176         3.597         3.530      0.067       0.981
# 60-day weight loss (%)      109         5.859         6.128     -0.269       0.759
#
#
#  STRATUM: Late (>60d)
#
#
# Pairs: 159
#
# Stratum Balance:
#           variable  treated_mean  control_mean    smd  abs_smd
#                age        48.623        49.132 -0.051    0.051
#       baseline_bmi        32.005        32.245 -0.056    0.056
# baseline_weight_kg        88.196        87.492  0.052    0.052
#         country_be         0.025         0.025  0.000    0.000
#         country_es         0.585         0.635 -0.103    0.103
#         country_it         0.252         0.208  0.104    0.104
#         country_pt         0.138         0.132  0.018    0.018
# landmark_weight_kg        74.214        74.206  0.001    0.001
#              sex_f         0.761         0.830 -0.172    0.172
#
# Trajectory Matching Diagnostics:
#                          variable  treated_mean  control_mean     smd  abs_smd
#     pre_landmark_slope_kg_per_day       -0.1349       -0.1305 -0.0769   0.0769
#           pairwise_abs_slope_dist           NaN           NaN     NaN   0.0403
# pairwise_abs_landmark_weight_dist           NaN           NaN     NaN   0.5270
#
# Outcome Summary:
#                outcome  n_pairs  treated_mean  control_mean  diff_mean  wilcoxon_p
#  Final weight loss (%)      147         2.743         2.321      0.422       0.288
# Final weight loss (kg)      147         2.104         1.814      0.290       0.339
# 30-day weight loss (%)       70         2.071         1.729      0.342       0.442
# 60-day weight loss (%)       52         3.965         3.230      0.735       0.145
#
#
#  STRATUM: Men
#
#
# Pairs: 188
#
#
#  BUILD PRIMARY FULL-COURSE TRAJECTORY PLOT
#
#
#
# Stratum Balance:
#           variable  treated_mean  control_mean    smd  abs_smd
#                age        50.750        47.011  0.405    0.405
#       baseline_bmi        32.368        34.096 -0.413    0.413
# baseline_weight_kg        99.227        98.465  0.058    0.058
#         country_be         0.016         0.016  0.000    0.000
#         country_es         0.660         0.707 -0.103    0.103
#         country_it         0.218         0.207  0.026    0.026
#         country_pt         0.106         0.069  0.132    0.132
# landmark_weight_kg        89.235        89.213  0.002    0.002
#              sex_f         0.000         0.612 -1.770    1.770
#
# Trajectory Matching Diagnostics:
#                          variable  treated_mean  control_mean     smd  abs_smd
#     pre_landmark_slope_kg_per_day        -0.284       -0.2714 -0.0704   0.0704
#           pairwise_abs_slope_dist           NaN           NaN     NaN   0.0481
# pairwise_abs_landmark_weight_dist           NaN           NaN     NaN   0.5410
#
# Outcome Summary:
#                outcome  n_pairs  treated_mean  control_mean  diff_mean  wilcoxon_p
#  Final weight loss (%)      187         5.135         6.171     -1.037       0.170
# Final weight loss (kg)      187         4.834         5.784     -0.950       0.189
# 30-day weight loss (%)      118         3.767         4.035     -0.267       0.342
# 60-day weight loss (%)       73         6.202         6.758     -0.556       0.453
#
#
#  STRATUM: Men - Early (≤30d)
#
#
# Pairs: 88
#
# Stratum Balance:
#           variable  treated_mean  control_mean    smd  abs_smd
#                age        49.966        45.398  0.522    0.522
#       baseline_bmi        32.242        33.765 -0.373    0.373
# baseline_weight_kg        99.019        98.541  0.036    0.036
#         country_es         0.761         0.761  0.000    0.000
#         country_it         0.159         0.182 -0.060    0.060
#         country_pt         0.080         0.057  0.090    0.090
# landmark_weight_kg        92.105        92.043  0.005    0.005
#              sex_f         0.000         0.580 -1.651    1.651
#
# Trajectory Matching Diagnostics:
#                          variable  treated_mean  control_mean     smd  abs_smd
#     pre_landmark_slope_kg_per_day        -0.357       -0.3534 -0.0162   0.0162
#           pairwise_abs_slope_dist           NaN           NaN     NaN   0.0506
# pairwise_abs_landmark_weight_dist           NaN           NaN     NaN   0.5659
#
# Outcome Summary:
#                outcome  n_pairs  treated_mean  control_mean  diff_mean  wilcoxon_p
#  Final weight loss (%)       88         7.006         7.998     -0.992       0.720
# Final weight loss (kg)       88         6.660         7.652     -0.992       0.662
# 30-day weight loss (%)       59         4.646         4.849     -0.203       0.774
# 60-day weight loss (%)       38         7.886         7.854      0.032       0.920
#
#
#  STRATUM: Men - Mid (30-60d)
#
#
# Pairs: 62
#
# Stratum Balance:
#           variable  treated_mean  control_mean    smd  abs_smd
#                age        49.774        46.919  0.284    0.284
#       baseline_bmi        32.163        34.060 -0.461    0.461
# baseline_weight_kg        98.960        97.839  0.083    0.083
#         country_be         0.032         0.032  0.000    0.000
#         country_es         0.613         0.694 -0.169    0.169
#         country_it         0.226         0.210  0.039    0.039
#         country_pt         0.129         0.065  0.218    0.218
# landmark_weight_kg        88.653        88.653 -0.000    0.000
#              sex_f         0.000         0.629 -1.827    1.827
#
# Trajectory Matching Diagnostics:
#                          variable  treated_mean  control_mean     smd  abs_smd
#     pre_landmark_slope_kg_per_day       -0.2552       -0.2291 -0.3519   0.3519
#           pairwise_abs_slope_dist           NaN           NaN     NaN   0.0466
# pairwise_abs_landmark_weight_dist           NaN           NaN     NaN   0.5323
#
# Outcome Summary:
#                outcome  n_pairs  treated_mean  control_mean  diff_mean  wilcoxon_p
#  Final weight loss (%)       62         4.558         5.413     -0.855       0.298
# Final weight loss (kg)       62         4.223         4.998     -0.776       0.259
# 30-day weight loss (%)       40         3.626         3.743     -0.117       0.675
# 60-day weight loss (%)       26         4.800         6.088     -1.288       0.208
#
#
#  STRATUM: Men - Late (>60d)
#
#
# Pairs: 38
# WARNING: Low pair count.
#
# Stratum Balance:
#           variable  treated_mean  control_mean    smd  abs_smd
#                age        54.158        50.895  0.399    0.399
#       baseline_bmi        32.991        34.921 -0.424    0.424
# baseline_weight_kg       100.142        99.311  0.065    0.065
#         country_be         0.026         0.026  0.000    0.000
#         country_es         0.500         0.605 -0.210    0.210
#         country_it         0.342         0.263  0.170    0.170
#         country_pt         0.132         0.105  0.080    0.080
# landmark_weight_kg        83.539        83.574 -0.003    0.003
#              sex_f         0.000         0.658 -1.935    1.935
#
# Trajectory Matching Diagnostics:
#                          variable  treated_mean  control_mean     smd  abs_smd
#     pre_landmark_slope_kg_per_day       -0.1618       -0.1508 -0.1732   0.1732
#           pairwise_abs_slope_dist           NaN           NaN     NaN   0.0447
# pairwise_abs_landmark_weight_dist           NaN           NaN     NaN   0.4974
#
# Outcome Summary:
#                outcome  n_pairs  treated_mean  control_mean  diff_mean  wilcoxon_p
#  Final weight loss (%)       37         1.651         3.097     -1.446       0.162
# Final weight loss (kg)       37         1.516         2.657     -1.141       0.179
# 30-day weight loss (%)       19         1.334         2.119     -0.785       0.258
#
#
#  STRATUM: Women
#
#
# Pairs: 695
#
#  BUILD PRIMARY FULL-COURSE TRAJECTORY PLOT
#
#
#
# Stratum Balance:
#           variable  treated_mean  control_mean    smd  abs_smd
#                age        47.053        48.688 -0.163    0.163
#       baseline_bmi        31.124        30.708  0.110    0.110
# baseline_weight_kg        83.022        82.804  0.019    0.019
#         country_be         0.013         0.012  0.013    0.013
#         country_ch         0.000         0.001 -0.054    0.054
#         country_es         0.734         0.740 -0.013    0.013
#         country_it         0.165         0.167 -0.004    0.004
#         country_pt         0.088         0.081  0.026    0.026
# landmark_weight_kg        75.777        75.777  0.000    0.000
#              sex_f         1.000         0.863  0.562    0.562
#
# Trajectory Matching Diagnostics:
#                          variable  treated_mean  control_mean     smd  abs_smd
#     pre_landmark_slope_kg_per_day       -0.2072       -0.2057 -0.0167   0.0167
#           pairwise_abs_slope_dist           NaN           NaN     NaN   0.0445
# pairwise_abs_landmark_weight_dist           NaN           NaN     NaN   0.5115
#
# Outcome Summary:
#                outcome  n_pairs  treated_mean  control_mean  diff_mean  wilcoxon_p
#  Final weight loss (%)      684         6.625         5.368      1.257       0.000
# Final weight loss (kg)      684         5.219         4.223      0.996       0.000
# 30-day weight loss (%)      410         3.869         3.660      0.209       0.282
# 60-day weight loss (%)      261         6.657         6.223      0.433       0.039
#
#
#  STRATUM: Women - Early (≤30d)
#
#
# Pairs: 335
#
# Stratum Balance:
#           variable  treated_mean  control_mean    smd  abs_smd
#                age        47.567        48.155 -0.057    0.057
#       baseline_bmi        31.086        30.496  0.160    0.160
# baseline_weight_kg        82.757        82.714  0.004    0.004
#         country_be         0.003         0.003  0.000    0.000
#         country_es         0.794         0.761  0.079    0.079
#         country_it         0.149         0.158 -0.025    0.025
#         country_pt         0.054         0.078 -0.096    0.096
# landmark_weight_kg        77.859        77.860 -0.000    0.000
#              sex_f         1.000         0.857  0.577    0.577
#
# Trajectory Matching Diagnostics:
#                          variable  treated_mean  control_mean    smd  abs_smd
#     pre_landmark_slope_kg_per_day       -0.2494       -0.2504 0.0108   0.0108
#           pairwise_abs_slope_dist           NaN           NaN    NaN   0.0463
# pairwise_abs_landmark_weight_dist           NaN           NaN    NaN   0.5048
#
# Outcome Summary:
#                outcome  n_pairs  treated_mean  control_mean  diff_mean  wilcoxon_p
#  Final weight loss (%)      335         8.078         6.461      1.618       0.000
# Final weight loss (kg)      335         6.471         5.180      1.291       0.001
# 30-day weight loss (%)      223         4.388         4.251      0.136       0.660
# 60-day weight loss (%)      135         7.746         7.283      0.462       0.183
#
#
#  STRATUM: Women - Mid (30-60d)
#
#
# Pairs: 239
#
# Stratum Balance:
#           variable  treated_mean  control_mean    smd  abs_smd
#                age        46.418        49.490 -0.321    0.321
#       baseline_bmi        30.888        30.653  0.062    0.062
# baseline_weight_kg        82.674        82.436  0.021    0.021
#         country_be         0.021         0.017  0.031    0.031
#         country_ch         0.000         0.004 -0.091    0.091
#         country_es         0.711         0.757 -0.104    0.104
#         country_it         0.159         0.167 -0.023    0.023
#         country_pt         0.109         0.054  0.199    0.199
# landmark_weight_kg        75.132        75.141 -0.001    0.001
#              sex_f         1.000         0.862  0.565    0.565
#
# Trajectory Matching Diagnostics:
#                          variable  treated_mean  control_mean     smd  abs_smd
#     pre_landmark_slope_kg_per_day       -0.1891       -0.1843 -0.0808   0.0808
#           pairwise_abs_slope_dist           NaN           NaN     NaN   0.0447
# pairwise_abs_landmark_weight_dist           NaN           NaN     NaN   0.5084
#
# Outcome Summary:
#                outcome  n_pairs  treated_mean  control_mean  diff_mean  wilcoxon_p
#  Final weight loss (%)      239         6.205         5.358      0.846       0.135
# Final weight loss (kg)      239         4.806         4.121      0.685       0.124
# 30-day weight loss (%)      136         3.589         3.468      0.121       0.837
# 60-day weight loss (%)       83         6.191         6.141      0.050       0.608
#
#
#  STRATUM: Women - Late (>60d)
#
#
# Pairs: 121
#
# Stratum Balance:
#           variable  treated_mean  control_mean    smd  abs_smd
#                age        46.884        48.579 -0.166    0.166
#       baseline_bmi        31.696        31.405  0.073    0.073
# baseline_weight_kg        84.444        83.781  0.057    0.057
#         country_be         0.025         0.025  0.000    0.000
#         country_es         0.612         0.645 -0.068    0.068
#         country_it         0.223         0.190  0.081    0.081
#         country_pt         0.140         0.140  0.000    0.000
# landmark_weight_kg        71.286        71.264  0.002    0.002
#              sex_f         1.000         0.884  0.509    0.509
#
# Trajectory Matching Diagnostics:
#                          variable  treated_mean  control_mean     smd  abs_smd
#     pre_landmark_slope_kg_per_day       -0.1264       -0.1241 -0.0433   0.0433
#           pairwise_abs_slope_dist           NaN           NaN     NaN   0.0389
# pairwise_abs_landmark_weight_dist           NaN           NaN     NaN   0.5364
#
# Outcome Summary:
#                outcome  n_pairs  treated_mean  control_mean  diff_mean  wilcoxon_p
#  Final weight loss (%)      110         3.110         2.061      1.050       0.036
# Final weight loss (kg)      110         2.302         1.531      0.771       0.039
# 30-day weight loss (%)       51         2.346         1.584      0.762       0.081
# 60-day weight loss (%)       43         4.137         3.055      1.083       0.062
#
#
#  STRATUM: BMI < 30
#
#
# Pairs: 362
#
#
#  BUILD PRIMARY FULL-COURSE TRAJECTORY PLOT
#
#
#
# Stratum Balance:
#           variable  treated_mean  control_mean    smd  abs_smd
#                age        47.577        47.489  0.009    0.009
#       baseline_bmi        27.650        28.757 -0.528    0.528
# baseline_weight_kg        76.178        76.071  0.013    0.013
#         country_be         0.014         0.011  0.025    0.025
#         country_ch         0.000         0.003 -0.074    0.074
#         country_es         0.735         0.820 -0.207    0.207
#         country_it         0.163         0.119  0.127    0.127
#         country_pt         0.088         0.047  0.165    0.165
# landmark_weight_kg        69.803        69.816 -0.002    0.002
#              sex_f         0.829         0.920 -0.277    0.277
#
# Trajectory Matching Diagnostics:
#                          variable  treated_mean  control_mean    smd  abs_smd
#     pre_landmark_slope_kg_per_day       -0.1916       -0.1906 -0.011   0.0110
#           pairwise_abs_slope_dist           NaN           NaN    NaN   0.0432
# pairwise_abs_landmark_weight_dist           NaN           NaN    NaN   0.5196
#
# Outcome Summary:
#                outcome  n_pairs  treated_mean  control_mean  diff_mean  wilcoxon_p
#  Final weight loss (%)      359         4.596         4.450      0.146       0.701
# Final weight loss (kg)      359         3.233         3.153      0.081       0.744
# 30-day weight loss (%)      217         3.496         3.472      0.023       0.955
# 60-day weight loss (%)      125         5.538         5.760     -0.221       0.733
#
#
#  STRATUM: BMI < 30 - Early (≤30d)
#
#
# Pairs: 172
#
# Stratum Balance:
#           variable  treated_mean  control_mean    smd  abs_smd
#                age        48.151        46.907  0.125    0.125
#       baseline_bmi        27.639        28.544 -0.438    0.438
# baseline_weight_kg        75.574        75.497  0.010    0.010
#         country_be         0.006         0.006  0.000    0.000
#         country_es         0.779         0.837 -0.148    0.148
#         country_it         0.157         0.093  0.194    0.194
#         country_pt         0.058         0.064 -0.024    0.024
# landmark_weight_kg        71.044        71.039  0.001    0.001
#              sex_f         0.831         0.936 -0.330    0.330
#
# Trajectory Matching Diagnostics:
#                          variable  treated_mean  control_mean    smd  abs_smd
#     pre_landmark_slope_kg_per_day       -0.2321       -0.2348 0.0285   0.0285
#           pairwise_abs_slope_dist           NaN           NaN    NaN   0.0449
# pairwise_abs_landmark_weight_dist           NaN           NaN    NaN   0.5297
#
# Outcome Summary:
#                outcome  n_pairs  treated_mean  control_mean  diff_mean  wilcoxon_p
#  Final weight loss (%)      172         6.158         5.462      0.695       0.268
# Final weight loss (kg)      172         4.373         3.945      0.428       0.352
# 30-day weight loss (%)      119         4.083         3.993      0.090       0.789
# 60-day weight loss (%)       63         6.972         6.741      0.230       0.768
#
#
#  STRATUM: BMI < 30 - Mid (30-60d)
#
#
# Pairs: 133
#
# Stratum Balance:
#           variable  treated_mean  control_mean    smd  abs_smd
#                age        46.962        48.241 -0.132    0.132
#       baseline_bmi        27.527        28.689 -0.579    0.579
# baseline_weight_kg        76.062        75.795  0.032    0.032
#         country_be         0.023         0.015  0.055    0.055
#         country_ch         0.000         0.008 -0.123    0.123
#         country_es         0.722         0.827 -0.253    0.253
#         country_it         0.143         0.120  0.067    0.067
#         country_pt         0.113         0.030  0.324    0.324
# landmark_weight_kg        69.126        69.155 -0.004    0.004
#              sex_f         0.835         0.917 -0.252    0.252
#
# Trajectory Matching Diagnostics:
#                          variable  treated_mean  control_mean     smd  abs_smd
#     pre_landmark_slope_kg_per_day       -0.1731       -0.1663 -0.1316   0.1316
#           pairwise_abs_slope_dist           NaN           NaN     NaN   0.0441
# pairwise_abs_landmark_weight_dist           NaN           NaN     NaN   0.5195
#
# Outcome Summary:
#                outcome  n_pairs  treated_mean  control_mean  diff_mean  wilcoxon_p
#  Final weight loss (%)      133         4.068         4.198     -0.130       0.962
# Final weight loss (kg)      133         2.826         2.901     -0.074       0.943
# 30-day weight loss (%)       75         3.135         3.200     -0.066       0.776
# 60-day weight loss (%)       43         4.818         5.581     -0.763       0.469
#
#
#  STRATUM: BMI < 30 - Late (>60d)
#
#
# Pairs: 57
#
# Stratum Balance:
#           variable  treated_mean  control_mean    smd  abs_smd
#                age        47.281        47.491 -0.022    0.022
#       baseline_bmi        27.972        29.556 -0.692    0.692
# baseline_weight_kg        78.270        78.449 -0.019    0.019
#         country_be         0.018         0.018  0.000    0.000
#         country_es         0.632         0.754 -0.266    0.266
#         country_it         0.228         0.193  0.085    0.085
#         country_pt         0.123         0.035  0.327    0.327
# landmark_weight_kg        67.640        67.670 -0.004    0.004
#              sex_f         0.807         0.877 -0.192    0.192
#
# Trajectory Matching Diagnostics:
#                          variable  treated_mean  control_mean    smd  abs_smd
#     pre_landmark_slope_kg_per_day       -0.1124       -0.1142 0.0349   0.0349
#           pairwise_abs_slope_dist           NaN           NaN    NaN   0.0356
# pairwise_abs_landmark_weight_dist           NaN           NaN    NaN   0.4895
#
# Outcome Summary:
#                outcome  n_pairs  treated_mean  control_mean  diff_mean  wilcoxon_p
#  Final weight loss (%)       54         0.923         1.847     -0.925       0.236
# Final weight loss (kg)       54         0.604         1.250     -0.646       0.204
# 30-day weight loss (%)       23         1.632         1.663     -0.031       1.000
# 60-day weight loss (%)       19         2.417         2.910     -0.493       0.679
#
#
#  STRATUM: BMI ≥ 30
#
#
# Pairs: 521
#
#
#  BUILD PRIMARY FULL-COURSE TRAJECTORY PLOT
#
#
# Stratum Balance:
#           variable  treated_mean  control_mean    smd  abs_smd
#                age        48.023        48.916 -0.089    0.089
#       baseline_bmi        33.986        33.287  0.204    0.204
# baseline_weight_kg        93.625        93.134  0.042    0.042
#         country_be         0.013         0.013  0.000    0.000
#         country_es         0.706         0.672  0.075    0.075
#         country_it         0.186         0.215 -0.072    0.072
#         country_pt         0.094         0.100 -0.019    0.019
# landmark_weight_kg        84.784        84.767  0.002    0.002
#              sex_f         0.758         0.733  0.057    0.057
#
# Trajectory Matching Diagnostics:
#                          variable  treated_mean  control_mean     smd  abs_smd
#     pre_landmark_slope_kg_per_day       -0.2458       -0.2399 -0.0442   0.0442
#           pairwise_abs_slope_dist           NaN           NaN     NaN   0.0467
# pairwise_abs_landmark_weight_dist           NaN           NaN     NaN   0.5165
#
# Outcome Summary:
#                outcome  n_pairs  treated_mean  control_mean  diff_mean  wilcoxon_p
#  Final weight loss (%)      512         7.503         6.305      1.198       0.001
# Final weight loss (kg)      512         6.471         5.544      0.927       0.001
# 30-day weight loss (%)      311         4.091         3.933      0.158       0.516
# 60-day weight loss (%)      209         7.167         6.687      0.479       0.078
#
#
#  STRATUM: BMI ≥ 30 - Early (≤30d)
#
#
# Pairs: 251
#
# Stratum Balance:
#           variable  treated_mean  control_mean    smd  abs_smd
#                age        48.008        48.044 -0.004    0.004
#       baseline_bmi        33.853        32.980  0.265    0.265
# baseline_weight_kg        93.380        93.209  0.015    0.015
#         country_es         0.793         0.709  0.194    0.194
#         country_it         0.147         0.211 -0.166    0.166
#         country_pt         0.060         0.080 -0.078    0.078
# landmark_weight_kg        87.524        87.507  0.002    0.002
#              sex_f         0.765         0.705  0.135    0.135
#
# Trajectory Matching Diagnostics:
#                          variable  treated_mean  control_mean     smd  abs_smd
#     pre_landmark_slope_kg_per_day       -0.2989       -0.2973 -0.0105   0.0105
#           pairwise_abs_slope_dist           NaN           NaN     NaN   0.0488
# pairwise_abs_landmark_weight_dist           NaN           NaN     NaN   0.5092
#
# Outcome Summary:
#                outcome  n_pairs  treated_mean  control_mean  diff_mean  wilcoxon_p
#  Final weight loss (%)      251         9.018         7.684      1.335       0.010
# Final weight loss (kg)      251         7.975         6.894      1.081       0.012
# 30-day weight loss (%)      163         4.704         4.656      0.048       0.913
# 60-day weight loss (%)      110         8.238         7.791      0.447       0.249
#
#
#  STRATUM: BMI ≥ 30 - Mid (30-60d)
#
#
# Pairs: 168
#
# Stratum Balance:
#           variable  treated_mean  control_mean    smd  abs_smd
#                age        47.226        49.530 -0.235    0.235
#       baseline_bmi        34.019        33.465  0.166    0.166
# baseline_weight_kg        93.918        93.377  0.047    0.047
#         country_be         0.024         0.024  0.000    0.000
#         country_es         0.667         0.679 -0.025    0.025
#         country_it         0.196         0.220 -0.058    0.058
#         country_pt         0.113         0.077  0.122    0.122
# landmark_weight_kg        84.877        84.867  0.001    0.001
#              sex_f         0.762         0.732  0.068    0.068
#
# Trajectory Matching Diagnostics:
#                          variable  treated_mean  control_mean     smd  abs_smd
#     pre_landmark_slope_kg_per_day       -0.2262       -0.2151 -0.1616   0.1616
#           pairwise_abs_slope_dist           NaN           NaN     NaN   0.0459
# pairwise_abs_landmark_weight_dist           NaN           NaN     NaN   0.5083
#
# Outcome Summary:
#                outcome  n_pairs  treated_mean  control_mean  diff_mean  wilcoxon_p
#  Final weight loss (%)      168         7.289         6.297      0.991       0.186
# Final weight loss (kg)      168         6.158         5.411      0.748       0.232
# 30-day weight loss (%)      101         3.941         3.776      0.165       0.772
# 60-day weight loss (%)       66         6.537         6.485      0.052       0.816
#
#
#  STRATUM: BMI ≥ 30 - Late (>60d)
#
#
# Pairs: 102
#
# Stratum Balance:
#           variable  treated_mean  control_mean    smd  abs_smd
#                age        49.373        50.049 -0.067    0.067
#       baseline_bmi        34.259        33.748  0.131    0.131
# baseline_weight_kg        93.742        92.546  0.093    0.093
#         country_be         0.029         0.029  0.000    0.000
#         country_es         0.559         0.569 -0.020    0.020
#         country_it         0.265         0.216  0.114    0.114
#         country_pt         0.147         0.186 -0.105    0.105
# landmark_weight_kg        77.888        77.858  0.003    0.003
#              sex_f         0.735         0.804 -0.163    0.163
#
# Trajectory Matching Diagnostics:
#                          variable  treated_mean  control_mean    smd  abs_smd
#     pre_landmark_slope_kg_per_day       -0.1474       -0.1396 -0.137   0.1370
#           pairwise_abs_slope_dist           NaN           NaN    NaN   0.0429
# pairwise_abs_landmark_weight_dist           NaN           NaN    NaN   0.5480
#
# Outcome Summary:
#                outcome  n_pairs  treated_mean  control_mean  diff_mean  wilcoxon_p
#  Final weight loss (%)       93         3.800         2.597      1.203       0.037
# Final weight loss (kg)       93         2.975         2.142      0.833       0.052
# 30-day weight loss (%)       47         2.286         1.761      0.525       0.281
# 60-day weight loss (%)       33         4.856         3.414      1.442       0.044
#
#
#  STRATUM: Age tertile 1
#
#
# Pairs: 300
#
#
#  BUILD PRIMARY FULL-COURSE TRAJECTORY PLOT
#
#
#
# Stratum Balance:
#           variable  treated_mean  control_mean    smd  abs_smd
#                age        36.967        43.223 -0.755    0.755
#       baseline_bmi        31.351        30.790  0.143    0.143
# baseline_weight_kg        86.354        85.599  0.056    0.056
#         country_be         0.013         0.010  0.031    0.031
#         country_ch         0.000         0.003 -0.082    0.082
#         country_es         0.653         0.797 -0.325    0.325
#         country_it         0.180         0.130  0.138    0.138
#         country_pt         0.153         0.060  0.305    0.305
# landmark_weight_kg        78.059        78.088 -0.002    0.002
#              sex_f         0.860         0.827  0.092    0.092
#
# Trajectory Matching Diagnostics:
#                          variable  treated_mean  control_mean    smd  abs_smd
#     pre_landmark_slope_kg_per_day       -0.2243       -0.2134 -0.116   0.1160
#           pairwise_abs_slope_dist           NaN           NaN    NaN   0.0459
# pairwise_abs_landmark_weight_dist           NaN           NaN    NaN   0.5217
#
# Outcome Summary:
#                outcome  n_pairs  treated_mean  control_mean  diff_mean  wilcoxon_p
#  Final weight loss (%)      296         6.412         4.480      1.932       0.000
# Final weight loss (kg)      296         5.206         3.616      1.591       0.000
# 30-day weight loss (%)      152         3.846         3.775      0.071       0.745
# 60-day weight loss (%)       93         6.738         6.374      0.364       0.371
#
#
#  STRATUM: Age tertile 1 - Early (≤30d)
#
#
# Pairs: 134
#
# Stratum Balance:
#           variable  treated_mean  control_mean    smd  abs_smd
#                age        36.448        41.582 -0.626    0.626
#       baseline_bmi        31.217        30.489  0.190    0.190
# baseline_weight_kg        85.643        85.442  0.015    0.015
#         country_es         0.724         0.843 -0.292    0.292
#         country_it         0.172         0.104  0.195    0.195
#         country_pt         0.104         0.052  0.195    0.195
# landmark_weight_kg        80.293        80.294 -0.000    0.000
#              sex_f         0.873         0.821  0.145    0.145
#
# Trajectory Matching Diagnostics:
#                          variable  treated_mean  control_mean     smd  abs_smd
#     pre_landmark_slope_kg_per_day       -0.2637       -0.2615 -0.0215   0.0215
#           pairwise_abs_slope_dist           NaN           NaN     NaN   0.0491
# pairwise_abs_landmark_weight_dist           NaN           NaN     NaN   0.5239
#
# Outcome Summary:
#                outcome  n_pairs  treated_mean  control_mean  diff_mean  wilcoxon_p
#  Final weight loss (%)      134         8.103         5.140      2.963       0.000
# Final weight loss (kg)      134         6.678         4.354      2.324       0.001
# 30-day weight loss (%)       73         4.432         4.162      0.271       0.424
# 60-day weight loss (%)       43         8.347         7.011      1.335       0.049
#
#
#  STRATUM: Age tertile 1 - Mid (30-60d)
#
#
# Pairs: 113
#
# Stratum Balance:
#           variable  treated_mean  control_mean    smd  abs_smd
#                age        37.177        44.947 -0.960    0.960
#       baseline_bmi        31.255        30.875  0.097    0.097
# baseline_weight_kg        86.697        85.780  0.067    0.067
#         country_be         0.018         0.009  0.077    0.077
#         country_ch         0.000         0.009 -0.133    0.133
#         country_es         0.602         0.779 -0.388    0.388
#         country_it         0.177         0.150  0.071    0.071
#         country_pt         0.204         0.053  0.460    0.460
# landmark_weight_kg        78.131        78.193 -0.005    0.005
#              sex_f         0.823         0.823  0.000    0.000
#
# Trajectory Matching Diagnostics:
#                          variable  treated_mean  control_mean    smd  abs_smd
#     pre_landmark_slope_kg_per_day        -0.216       -0.1966 -0.296   0.2960
#           pairwise_abs_slope_dist           NaN           NaN    NaN   0.0466
# pairwise_abs_landmark_weight_dist           NaN           NaN    NaN   0.5062
#
# Outcome Summary:
#                outcome  n_pairs  treated_mean  control_mean  diff_mean  wilcoxon_p
#  Final weight loss (%)      113         5.740         4.577      1.163       0.137
# Final weight loss (kg)      113         4.605         3.546      1.059       0.114
# 30-day weight loss (%)       61         3.544         3.693     -0.149       0.603
# 60-day weight loss (%)       32         5.597         6.839     -1.242       0.178
#
#
#  STRATUM: Age tertile 1 - Late (>60d)
#
#
# Pairs: 53
#
# Stratum Balance:
#           variable  treated_mean  control_mean    smd  abs_smd
#                age        37.830        43.698 -0.685    0.685
#       baseline_bmi        31.894        31.371  0.125    0.125
# baseline_weight_kg        87.419        85.609  0.134    0.134
#         country_be         0.038         0.038  0.000    0.000
#         country_es         0.585         0.717 -0.277    0.277
#         country_it         0.208         0.151  0.147    0.147
#         country_pt         0.170         0.094  0.222    0.222
# landmark_weight_kg        72.258        72.287 -0.003    0.003
#              sex_f         0.906         0.849  0.172    0.172
#
# Trajectory Matching Diagnostics:
#                          variable  treated_mean  control_mean     smd  abs_smd
#     pre_landmark_slope_kg_per_day       -0.1423       -0.1276 -0.3082   0.3082
#           pairwise_abs_slope_dist           NaN           NaN     NaN   0.0366
# pairwise_abs_landmark_weight_dist           NaN           NaN     NaN   0.5491
#
# Outcome Summary:
#                outcome  n_pairs  treated_mean  control_mean  diff_mean  wilcoxon_p
#  Final weight loss (%)       49         3.340         2.452      0.888       0.424
# Final weight loss (kg)       49         2.569         1.759      0.810       0.336
# 30-day weight loss (%)       18         2.488         2.483      0.005       1.000
# 60-day weight loss (%)       18         4.922         4.024      0.898       0.495
#
#
#  STRATUM: Age tertile 2
#
#
# Pairs: 297
#
#
#  BUILD PRIMARY FULL-COURSE TRAJECTORY PLOT
#
#
#
# Stratum Balance:
#           variable  treated_mean  control_mean    smd  abs_smd
#                age        48.431        48.589 -0.028    0.028
#       baseline_bmi        31.367        31.289  0.019    0.019
# baseline_weight_kg        86.575        86.317  0.020    0.020
#         country_be         0.013         0.013  0.000    0.000
#         country_es         0.774         0.788 -0.033    0.033
#         country_it         0.148         0.125  0.069    0.069
#         country_pt         0.064         0.074 -0.040    0.040
# landmark_weight_kg        78.935        78.906  0.002    0.002
#              sex_f         0.785         0.801 -0.041    0.041
#
# Trajectory Matching Diagnostics:
#                          variable  treated_mean  control_mean     smd  abs_smd
#     pre_landmark_slope_kg_per_day       -0.2227       -0.2209 -0.0174   0.0174
#           pairwise_abs_slope_dist           NaN           NaN     NaN   0.0440
# pairwise_abs_landmark_weight_dist           NaN           NaN     NaN   0.5057
#
# Outcome Summary:
#                outcome  n_pairs  treated_mean  control_mean  diff_mean  wilcoxon_p
#  Final weight loss (%)      290         6.811         5.521      1.290       0.007
# Final weight loss (kg)      290         5.562         4.569      0.993       0.011
# 30-day weight loss (%)      192         4.035         3.491      0.544       0.047
# 60-day weight loss (%)      121         6.995         5.844      1.152       0.002
#
#
#  STRATUM: Age tertile 2 - Early (≤30d)
#
#
# Pairs: 149
#
# Stratum Balance:
#           variable  treated_mean  control_mean    smd  abs_smd
#                age        48.443        48.591 -0.027    0.027
#       baseline_bmi        31.385        31.215  0.044    0.044
# baseline_weight_kg        87.135        86.901  0.018    0.018
#         country_es         0.805         0.812 -0.017    0.017
#         country_it         0.128         0.114  0.041    0.041
#         country_pt         0.067         0.074 -0.026    0.026
# landmark_weight_kg        81.415        81.364  0.004    0.004
#              sex_f         0.732         0.785 -0.125    0.125
#
# Trajectory Matching Diagnostics:
#                          variable  treated_mean  control_mean     smd  abs_smd
#     pre_landmark_slope_kg_per_day       -0.2752       -0.2743 -0.0091   0.0091
#           pairwise_abs_slope_dist           NaN           NaN     NaN   0.0471
# pairwise_abs_landmark_weight_dist           NaN           NaN     NaN   0.5154
#
# Outcome Summary:
#                outcome  n_pairs  treated_mean  control_mean  diff_mean  wilcoxon_p
#  Final weight loss (%)      149         7.578         6.698      0.881       0.111
# Final weight loss (kg)      149         6.305         5.632      0.673       0.124
# 30-day weight loss (%)      108         4.371         4.304      0.068       0.936
# 60-day weight loss (%)       61         7.946         7.006      0.940       0.089
#
#
#  STRATUM: Age tertile 2 - Mid (30-60d)
#
#
# Pairs: 99
#
# Stratum Balance:
#           variable  treated_mean  control_mean    smd  abs_smd
#                age        48.242        48.828 -0.097    0.097
#       baseline_bmi        30.952        31.111 -0.039    0.039
# baseline_weight_kg        84.835        84.560  0.021    0.021
#         country_be         0.030         0.030  0.000    0.000
#         country_es         0.737         0.778 -0.094    0.094
#         country_it         0.182         0.141  0.109    0.109
#         country_pt         0.051         0.051  0.000    0.000
# landmark_weight_kg        76.946        76.944  0.000    0.000
#              sex_f         0.859         0.818  0.109    0.109
#
# Trajectory Matching Diagnostics:
#                          variable  treated_mean  control_mean    smd  abs_smd
#     pre_landmark_slope_kg_per_day       -0.1886       -0.1856 -0.047   0.0470
#           pairwise_abs_slope_dist           NaN           NaN    NaN   0.0416
# pairwise_abs_landmark_weight_dist           NaN           NaN    NaN   0.4889
#
# Outcome Summary:
#                outcome  n_pairs  treated_mean  control_mean  diff_mean  wilcoxon_p
#  Final weight loss (%)       99         6.996         5.008      1.988       0.066
# Final weight loss (kg)       99         5.568         4.043      1.524       0.094
# 30-day weight loss (%)       59         3.820         2.946      0.875       0.051
# 60-day weight loss (%)       39         6.833         5.379      1.455       0.040
#
#
#  STRATUM: Age tertile 2 - Late (>60d)
#
#
# Pairs: 49
#
# Stratum Balance:
#           variable  treated_mean  control_mean    smd  abs_smd
#                age        48.776        48.102  0.122    0.122
#       baseline_bmi        32.148        31.877  0.065    0.065
# baseline_weight_kg        88.388        88.092  0.023    0.023
#         country_be         0.020         0.020  0.000    0.000
#         country_es         0.755         0.735  0.046    0.046
#         country_it         0.143         0.122  0.060    0.060
#         country_pt         0.082         0.122 -0.134    0.134
# landmark_weight_kg        75.414        75.394  0.002    0.002
#              sex_f         0.796         0.816 -0.051    0.051
#
# Trajectory Matching Diagnostics:
#                          variable  treated_mean  control_mean     smd  abs_smd
#     pre_landmark_slope_kg_per_day       -0.1321       -0.1301 -0.0294   0.0294
#           pairwise_abs_slope_dist           NaN           NaN     NaN   0.0395
# pairwise_abs_landmark_weight_dist           NaN           NaN     NaN   0.5102
#
# Outcome Summary:
#                outcome  n_pairs  treated_mean  control_mean  diff_mean  wilcoxon_p
#  Final weight loss (%)       42         3.649         2.553      1.097       0.141
# Final weight loss (kg)       42         2.912         2.036      0.876       0.140
# 30-day weight loss (%)       25         3.090         1.266      1.823       0.027
# 60-day weight loss (%)       21         4.534         3.330      1.204       0.179
#
#
#  STRATUM: Age tertile 3
#
#
# Pairs: 286
#
#
#  BUILD PRIMARY FULL-COURSE TRAJECTORY PLOT
#
#
#
# Stratum Balance:
#           variable  treated_mean  control_mean    smd  abs_smd
#                age        58.633        53.420  0.721    0.721
#       baseline_bmi        31.451        32.246 -0.196    0.196
# baseline_weight_kg        86.490        86.520 -0.002    0.002
#         country_be         0.014         0.014  0.000    0.000
#         country_es         0.727         0.608  0.254    0.254
#         country_it         0.203         0.276 -0.172    0.172
#         country_pt         0.056         0.101 -0.169    0.169
# landmark_weight_kg        78.950        78.935  0.001    0.001
#              sex_f         0.713         0.801 -0.205    0.205
#
# Trajectory Matching Diagnostics:
#                          variable  treated_mean  control_mean    smd  abs_smd
#     pre_landmark_slope_kg_per_day       -0.2238       -0.2251 0.0082   0.0082
#           pairwise_abs_slope_dist           NaN           NaN    NaN   0.0458
# pairwise_abs_landmark_weight_dist           NaN           NaN    NaN   0.5262
#
# Outcome Summary:
#                outcome  n_pairs  treated_mean  control_mean  diff_mean  wilcoxon_p
#  Final weight loss (%)      285         5.678         6.662     -0.983       0.205
# Final weight loss (kg)      285         4.630         5.526     -0.896       0.179
# 30-day weight loss (%)      184         3.649         3.981     -0.332       0.128
# 60-day weight loss (%)      120         5.976         6.815     -0.839       0.147
#
#
#  STRATUM: Age tertile 3 - Early (≤30d)
#
#
# Pairs: 140
#
# Stratum Balance:
#           variable  treated_mean  control_mean    smd  abs_smd
#                age        58.786        52.250  0.868    0.868
#       baseline_bmi        31.368        31.793 -0.108    0.108
# baseline_weight_kg        85.558        85.596 -0.003    0.003
#         country_be         0.007         0.007  0.000    0.000
#         country_es         0.829         0.629  0.460    0.460
#         country_it         0.157         0.271 -0.280    0.280
#         country_pt         0.007         0.093 -0.400    0.400
# landmark_weight_kg        80.700        80.716 -0.001    0.001
#              sex_f         0.779         0.793 -0.035    0.035
#
# Trajectory Matching Diagnostics:
#                          variable  treated_mean  control_mean    smd  abs_smd
#     pre_landmark_slope_kg_per_day       -0.2759       -0.2792 0.0171   0.0171
#           pairwise_abs_slope_dist           NaN           NaN    NaN   0.0456
# pairwise_abs_landmark_weight_dist           NaN           NaN    NaN   0.5136
#
# Outcome Summary:
#                outcome  n_pairs  treated_mean  control_mean  diff_mean  wilcoxon_p
#  Final weight loss (%)      140         7.913         8.439     -0.527       0.952
# Final weight loss (kg)      140         6.569         7.044     -0.476       0.974
# 30-day weight loss (%)      101         4.524         4.609     -0.085       0.741
# 60-day weight loss (%)       69         7.271         8.012     -0.741       0.267
#
#
#  STRATUM: Age tertile 3 - Mid (30-60d)
#
#
# Pairs: 89
#
# Stratum Balance:
#           variable  treated_mean  control_mean    smd  abs_smd
#                age        58.461        54.202  0.632    0.632
#       baseline_bmi        31.238        32.236 -0.249    0.249
# baseline_weight_kg        86.506        86.558 -0.004    0.004
#         country_be         0.022         0.022  0.000    0.000
#         country_es         0.753         0.663  0.198    0.198
#         country_it         0.157         0.247 -0.224    0.224
#         country_pt         0.067         0.067  0.000    0.000
# landmark_weight_kg        78.725        78.674  0.004    0.004
#              sex_f         0.685         0.798 -0.257    0.257
#
# Trajectory Matching Diagnostics:
#                          variable  treated_mean  control_mean     smd  abs_smd
#     pre_landmark_slope_kg_per_day       -0.2017       -0.1984 -0.0456   0.0456
#           pairwise_abs_slope_dist           NaN           NaN     NaN   0.0471
# pairwise_abs_landmark_weight_dist           NaN           NaN     NaN   0.5494
#
# Outcome Summary:
#                outcome  n_pairs  treated_mean  control_mean  diff_mean  wilcoxon_p
#  Final weight loss (%)       89         4.767         6.777     -2.010       0.044
# Final weight loss (kg)       89         3.808         5.548     -1.740       0.035
# 30-day weight loss (%)       56         3.420         3.969     -0.549       0.149
# 60-day weight loss (%)       38         5.079         6.299     -1.220       0.287
#
#  STRATUM: Age tertile 3 - Late (>60d)
#
#
# Pairs: 57
#
# Stratum Balance:
#           variable  treated_mean  control_mean    smd  abs_smd
#                age        58.526        55.070  0.489    0.489
#       baseline_bmi        31.987        33.374 -0.319    0.319
# baseline_weight_kg        88.753        88.728  0.002    0.002
#         country_be         0.018         0.018  0.000    0.000
#         country_es         0.439         0.474 -0.070    0.070
#         country_it         0.386         0.333  0.109    0.109
#         country_pt         0.158         0.175 -0.047    0.047
# landmark_weight_kg        75.002        74.968  0.003    0.003
#              sex_f         0.596         0.825 -0.515    0.515
#
# Trajectory Matching Diagnostics:
#                          variable  treated_mean  control_mean    smd  abs_smd
#     pre_landmark_slope_kg_per_day       -0.1304       -0.1336 0.0589   0.0589
#           pairwise_abs_slope_dist           NaN           NaN    NaN   0.0443
# pairwise_abs_landmark_weight_dist           NaN           NaN    NaN   0.5211
#
# Outcome Summary:
#                outcome  n_pairs  treated_mean  control_mean  diff_mean  wilcoxon_p
#  Final weight loss (%)       56         1.541         2.034     -0.493       0.860
# Final weight loss (kg)       56         1.091         1.696     -0.605       0.630
# 30-day weight loss (%)       27         0.850         1.655     -0.805       0.258
# 60-day weight loss (%)       13         1.719         1.967     -0.248       0.839

# %% [markdown]
# #### 16Jun25

# %% [markdown]
# **PROPOSED UPDATED NOTEBOOK AND PAPER STRUCTURE**
#
# **DATAPREP**
# - Creation and filtering of initial inclusion cohorts
# - PSM: baseline-matched pooled control group
#
# **GLOBAL CASE-CONTROL COMPARISONS**
# - Baseline-matched controls, pooled treated patients and treated patients stratified by timing groups
# - Table
# - Alluvial, KM and violin plots
# - Simple regression: descriptive association of personalization with outcomes, drawing on the global control and global case pools. Adjustments made for clinical variables present in both pools, no adjustments on immortal time that is not available in controls. Can be stratified by key variables.
#
# **COMPARISONS WITHIN TREATMENT STRATA**
# - Describing genomics timing dynamics
# - Effect of genomics on engagement
# - Total trajectory comparisons with genomics timing events annotated on trajectories
# - Post-personalization raw and adjusted trajectory comparisons
#
# **LANDMARK-MATCHED CASE-CONTROL COMPARISONS**
# - Matching all cases to a survival / adherence landmark-matched control
# - Printing appropriate balance checks
# - Printing outcomes (tablular) and trajectories (graphical) of the post-personalization period, both globally and by strata
#
# **POSSIBLE OTHERS**
# - tvCox
# - Nadir / regain analyses
#
# **BAD IDEAS**
# - Regressions, raw and adjusted for variables including immortal time, to predict weight loss and adherence of cases compared to baseline-matched controls, both globally and by strata
#     - in this case controls don't have the immortal time variable, so it would have to be imputed or something similar, which changes the estimand
#
# **GOOD IDEAS**
# - 'estimand map' in the notebook - clear statements of what each model estimates, what are the estimated outcomes - so that analyses are used and interpreted the way they should be.

# %% [markdown]
# #### 5Jun26

# %% [markdown]
# Yes: in the spline mixed model, the predictors are not predicting “weight loss” directly in the same simple way a linear regression does. They are predicting **absolute body weight over time**, and weight loss is obtained only by comparing predicted weight at later days to the day-0 predicted weight. [ppl-ai-file-upload.s3.amazonaws](https://ppl-ai-file-upload.s3.amazonaws.com/web/direct-files/attachments/images/8778350/5786a2c1-9041-48be-9fe4-2deaf70c5440/image.jpg?AWSAccessKeyId=ASIA2F3EMEYEWTLAVILQ&Signature=aK5nq6ZEb4T3kiAT%2BRBkTTWnlZc%3D&x-amz-security-token=IQoJb3JpZ2luX2VjEKL%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEaCXVzLWVhc3QtMSJHMEUCIEoalQjTv4S8g%2FaeyE3SQC7q1AD4rgBLfV3ra3bwALZpAiEA2vodrZU2gI6KnB%2BrF%2FUE%2B0xEmMdVb%2ByBCUZbRgwt6rMq8wQIaxABGgw2OTk3NTMzMDk3MDUiDGmpTJBIa0WHaKBCMSrQBEDxFXOV0I7DbumDzwn4fHoIGFFzfl3Sy2jjK3bf83%2BSCm9sSmJV9EnNOkCHZZkmX6k8ROntK7ygX2MwAO3f%2FVMBOKEE1XFH2dAwI9Xb461CYjN0pWUf0l4s9gpcgXGOfNJxEqEDSr9F3YxTyeqrrRgQ2PCv1idf1zxx%2FS5sM7W4oVi1DWhomXYUIA2AeLklheDAzsalD%2Bo%2B3V9izecjVHCPk%2BddhuPV%2BT4QuQmpCJrjJYJE0wsLdIasr7NqTq7%2BnFojSBTsv3%2BRbQNa71MCqQ%2Ba1sz41I%2BuR%2B1qa%2BI0kW%2Bz8RNLWMaSMXC%2Fsbriad01HpcbhSK8eAYKYGZIX02c%2BHNbByVuZGv5UyOjezvOxOyzAaff5k1zKhBn%2BkC68xKt%2F6OKqsJF1CN3ips2jFUtF0xbK%2FD9NqeVy35rhL5zObMOgtZameDBi4skat5in8Gffbcgal2fbUy7vppStMbszwukE36hDgrWSOQmbpfA0tYMqJPWbz8A9xKk390%2FouI14%2B8%2BaCB7ZdqmzbSUlxMchZM9ZUVC0mTABDfwVw4O7WOLpeMpFS7oGCS%2F23btJefhRznXQEmNj081OM%2FC3b2zNxHRg542iSPpnYs7Ss5BMZnDdqFdLAHCnjVkHvrOSgRllue4YvFoQNp%2FVCgasxOLBLP2qNN28llxQewDX6NqpYygbgoXydp5yOu2NxvwvJqv6gxO0zoAX9Pj7czsekjJ7qkKPBqyMg2Y4%2BtrfIVkw%2F%2Fn%2Bs0YVLBfBeKL9o2ipseF4zSvEo6ddJtqO0EWPXDnGaUwzLmK0QY6mAEW2gAIVjI1zv4bgb84CR5Xlx8c6b333Ey3l497oHhn2x9Lv6iSIhYUJOjhxbWHJPkja%2F11mklLyUxGp50hVqARc0XCLGD4c7vgBH5MCxClujU%2BGKIPir99UiCdgyie0EK11S5MuzmwRNQaY0uh01B0VLRNe0B3LwVLtIvB%2FdZO6t1V21iTUCKMiVUBVXYSR%2BM1zMOEqwMy0g%3D%3D&Expires=1780656799)
#
# What is being predicted
#
# In your mixed model, the dependent variable is `weight_kg`, so the model estimates expected body weight at each time point, conditional on cohort and covariates. The cohort-by-time spline terms shape the **trajectory**, not a single endpoint. [ppl-ai-file-upload.s3.amazonaws](https://ppl-ai-file-upload.s3.amazonaws.com/web/direct-files/attachments/images/8778350/5786a2c1-9041-48be-9fe4-2deaf70c5440/image.jpg?AWSAccessKeyId=ASIA2F3EMEYEWTLAVILQ&Signature=aK5nq6ZEb4T3kiAT%2BRBkTTWnlZc%3D&x-amz-security-token=IQoJb3JpZ2luX2VjEKL%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEaCXVzLWVhc3QtMSJHMEUCIEoalQjTv4S8g%2FaeyE3SQC7q1AD4rgBLfV3ra3bwALZpAiEA2vodrZU2gI6KnB%2BrF%2FUE%2B0xEmMdVb%2ByBCUZbRgwt6rMq8wQIaxABGgw2OTk3NTMzMDk3MDUiDGmpTJBIa0WHaKBCMSrQBEDxFXOV0I7DbumDzwn4fHoIGFFzfl3Sy2jjK3bf83%2BSCm9sSmJV9EnNOkCHZZkmX6k8ROntK7ygX2MwAO3f%2FVMBOKEE1XFH2dAwI9Xb461CYjN0pWUf0l4s9gpcgXGOfNJxEqEDSr9F3YxTyeqrrRgQ2PCv1idf1zxx%2FS5sM7W4oVi1DWhomXYUIA2AeLklheDAzsalD%2Bo%2B3V9izecjVHCPk%2BddhuPV%2BT4QuQmpCJrjJYJE0wsLdIasr7NqTq7%2BnFojSBTsv3%2BRbQNa71MCqQ%2Ba1sz41I%2BuR%2B1qa%2BI0kW%2Bz8RNLWMaSMXC%2Fsbriad01HpcbhSK8eAYKYGZIX02c%2BHNbByVuZGv5UyOjezvOxOyzAaff5k1zKhBn%2BkC68xKt%2F6OKqsJF1CN3ips2jFUtF0xbK%2FD9NqeVy35rhL5zObMOgtZameDBi4skat5in8Gffbcgal2fbUy7vppStMbszwukE36hDgrWSOQmbpfA0tYMqJPWbz8A9xKk390%2FouI14%2B8%2BaCB7ZdqmzbSUlxMchZM9ZUVC0mTABDfwVw4O7WOLpeMpFS7oGCS%2F23btJefhRznXQEmNj081OM%2FC3b2zNxHRg542iSPpnYs7Ss5BMZnDdqFdLAHCnjVkHvrOSgRllue4YvFoQNp%2FVCgasxOLBLP2qNN28llxQewDX6NqpYygbgoXydp5yOu2NxvwvJqv6gxO0zoAX9Pj7czsekjJ7qkKPBqyMg2Y4%2BtrfIVkw%2F%2Fn%2Bs0YVLBfBeKL9o2ipseF4zSvEo6ddJtqO0EWPXDnGaUwzLmK0QY6mAEW2gAIVjI1zv4bgb84CR5Xlx8c6b333Ey3l497oHhn2x9Lv6iSIhYUJOjhxbWHJPkja%2F11mklLyUxGp50hVqARc0XCLGD4c7vgBH5MCxClujU%2BGKIPir99UiCdgyie0EK11S5MuzmwRNQaY0uh01B0VLRNe0B3LwVLtIvB%2FdZO6t1V21iTUCKMiVUBVXYSR%2BM1zMOEqwMy0g%3D%3D&Expires=1780656799)
#
# That is different from your OLS fixed-time-point code, where the dependent variable is already `post_personalization_{x}d_wl_pct`, so the model directly predicts **weight-loss percentage** at each time point. [ppl-ai-file-upload.s3.amazonaws](https://ppl-ai-file-upload.s3.amazonaws.com/web/direct-files/attachments/images/8778350/5786a2c1-9041-48be-9fe4-2deaf70c5440/image.jpg?AWSAccessKeyId=ASIA2F3EMEYEWTLAVILQ&Signature=aK5nq6ZEb4T3kiAT%2BRBkTTWnlZc%3D&x-amz-security-token=IQoJb3JpZ2luX2VjEKL%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEaCXVzLWVhc3QtMSJHMEUCIEoalQjTv4S8g%2FaeyE3SQC7q1AD4rgBLfV3ra3bwALZpAiEA2vodrZU2gI6KnB%2BrF%2FUE%2B0xEmMdVb%2ByBCUZbRgwt6rMq8wQIaxABGgw2OTk3NTMzMDk3MDUiDGmpTJBIa0WHaKBCMSrQBEDxFXOV0I7DbumDzwn4fHoIGFFzfl3Sy2jjK3bf83%2BSCm9sSmJV9EnNOkCHZZkmX6k8ROntK7ygX2MwAO3f%2FVMBOKEE1XFH2dAwI9Xb461CYjN0pWUf0l4s9gpcgXGOfNJxEqEDSr9F3YxTyeqrrRgQ2PCv1idf1zxx%2FS5sM7W4oVi1DWhomXYUIA2AeLklheDAzsalD%2Bo%2B3V9izecjVHCPk%2BddhuPV%2BT4QuQmpCJrjJYJE0wsLdIasr7NqTq7%2BnFojSBTsv3%2BRbQNa71MCqQ%2Ba1sz41I%2BuR%2B1qa%2BI0kW%2Bz8RNLWMaSMXC%2Fsbriad01HpcbhSK8eAYKYGZIX02c%2BHNbByVuZGv5UyOjezvOxOyzAaff5k1zKhBn%2BkC68xKt%2F6OKqsJF1CN3ips2jFUtF0xbK%2FD9NqeVy35rhL5zObMOgtZameDBi4skat5in8Gffbcgal2fbUy7vppStMbszwukE36hDgrWSOQmbpfA0tYMqJPWbz8A9xKk390%2FouI14%2B8%2BaCB7ZdqmzbSUlxMchZM9ZUVC0mTABDfwVw4O7WOLpeMpFS7oGCS%2F23btJefhRznXQEmNj081OM%2FC3b2zNxHRg542iSPpnYs7Ss5BMZnDdqFdLAHCnjVkHvrOSgRllue4YvFoQNp%2FVCgasxOLBLP2qNN28llxQewDX6NqpYygbgoXydp5yOu2NxvwvJqv6gxO0zoAX9Pj7czsekjJ7qkKPBqyMg2Y4%2BtrfIVkw%2F%2Fn%2Bs0YVLBfBeKL9o2ipseF4zSvEo6ddJtqO0EWPXDnGaUwzLmK0QY6mAEW2gAIVjI1zv4bgb84CR5Xlx8c6b333Ey3l497oHhn2x9Lv6iSIhYUJOjhxbWHJPkja%2F11mklLyUxGp50hVqARc0XCLGD4c7vgBH5MCxClujU%2BGKIPir99UiCdgyie0EK11S5MuzmwRNQaY0uh01B0VLRNe0B3LwVLtIvB%2FdZO6t1V21iTUCKMiVUBVXYSR%2BM1zMOEqwMy0g%3D%3D&Expires=1780656799)
#
# Why this matters
#
# So yes, your comparison was slightly mismatched.
#
# - Mixed model: predicts **weight**
# - OLS model: predicts **weight loss percentage** at 30/60/90 days [ppl-ai-file-upload.s3.amazonaws](https://ppl-ai-file-upload.s3.amazonaws.com/web/direct-files/attachments/images/8778350/5786a2c1-9041-48be-9fe4-2deaf70c5440/image.jpg?AWSAccessKeyId=ASIA2F3EMEYEWTLAVILQ&Signature=aK5nq6ZEb4T3kiAT%2BRBkTTWnlZc%3D&x-amz-security-token=IQoJb3JpZ2luX2VjEKL%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEaCXVzLWVhc3QtMSJHMEUCIEoalQjTv4S8g%2FaeyE3SQC7q1AD4rgBLfV3ra3bwALZpAiEA2vodrZU2gI6KnB%2BrF%2FUE%2B0xEmMdVb%2ByBCUZbRgwt6rMq8wQIaxABGgw2OTk3NTMzMDk3MDUiDGmpTJBIa0WHaKBCMSrQBEDxFXOV0I7DbumDzwn4fHoIGFFzfl3Sy2jjK3bf83%2BSCm9sSmJV9EnNOkCHZZkmX6k8ROntK7ygX2MwAO3f%2FVMBOKEE1XFH2dAwI9Xb461CYjN0pWUf0l4s9gpcgXGOfNJxEqEDSr9F3YxTyeqrrRgQ2PCv1idf1zxx%2FS5sM7W4oVi1DWhomXYUIA2AeLklheDAzsalD%2Bo%2B3V9izecjVHCPk%2BddhuPV%2BT4QuQmpCJrjJYJE0wsLdIasr7NqTq7%2BnFojSBTsv3%2BRbQNa71MCqQ%2Ba1sz41I%2BuR%2B1qa%2BI0kW%2Bz8RNLWMaSMXC%2Fsbriad01HpcbhSK8eAYKYGZIX02c%2BHNbByVuZGv5UyOjezvOxOyzAaff5k1zKhBn%2BkC68xKt%2F6OKqsJF1CN3ips2jFUtF0xbK%2FD9NqeVy35rhL5zObMOgtZameDBi4skat5in8Gffbcgal2fbUy7vppStMbszwukE36hDgrWSOQmbpfA0tYMqJPWbz8A9xKk390%2FouI14%2B8%2BaCB7ZdqmzbSUlxMchZM9ZUVC0mTABDfwVw4O7WOLpeMpFS7oGCS%2F23btJefhRznXQEmNj081OM%2FC3b2zNxHRg542iSPpnYs7Ss5BMZnDdqFdLAHCnjVkHvrOSgRllue4YvFoQNp%2FVCgasxOLBLP2qNN28llxQewDX6NqpYygbgoXydp5yOu2NxvwvJqv6gxO0zoAX9Pj7czsekjJ7qkKPBqyMg2Y4%2BtrfIVkw%2F%2Fn%2Bs0YVLBfBeKL9o2ipseF4zSvEo6ddJtqO0EWPXDnGaUwzLmK0QY6mAEW2gAIVjI1zv4bgb84CR5Xlx8c6b333Ey3l497oHhn2x9Lv6iSIhYUJOjhxbWHJPkja%2F11mklLyUxGp50hVqARc0XCLGD4c7vgBH5MCxClujU%2BGKIPir99UiCdgyie0EK11S5MuzmwRNQaY0uh01B0VLRNe0B3LwVLtIvB%2FdZO6t1V21iTUCKMiVUBVXYSR%2BM1zMOEqwMy0g%3D%3D&Expires=1780656799)
#
# Those are related, but not the same estimand. The mixed model needs a subtraction from day 0 to become a weight-loss estimate. The OLS model already starts from loss. [ppl-ai-file-upload.s3.amazonaws](https://ppl-ai-file-upload.s3.amazonaws.com/web/direct-files/attachments/images/8778350/5786a2c1-9041-48be-9fe4-2deaf70c5440/image.jpg?AWSAccessKeyId=ASIA2F3EMEYEWTLAVILQ&Signature=aK5nq6ZEb4T3kiAT%2BRBkTTWnlZc%3D&x-amz-security-token=IQoJb3JpZ2luX2VjEKL%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEaCXVzLWVhc3QtMSJHMEUCIEoalQjTv4S8g%2FaeyE3SQC7q1AD4rgBLfV3ra3bwALZpAiEA2vodrZU2gI6KnB%2BrF%2FUE%2B0xEmMdVb%2ByBCUZbRgwt6rMq8wQIaxABGgw2OTk3NTMzMDk3MDUiDGmpTJBIa0WHaKBCMSrQBEDxFXOV0I7DbumDzwn4fHoIGFFzfl3Sy2jjK3bf83%2BSCm9sSmJV9EnNOkCHZZkmX6k8ROntK7ygX2MwAO3f%2FVMBOKEE1XFH2dAwI9Xb461CYjN0pWUf0l4s9gpcgXGOfNJxEqEDSr9F3YxTyeqrrRgQ2PCv1idf1zxx%2FS5sM7W4oVi1DWhomXYUIA2AeLklheDAzsalD%2Bo%2B3V9izecjVHCPk%2BddhuPV%2BT4QuQmpCJrjJYJE0wsLdIasr7NqTq7%2BnFojSBTsv3%2BRbQNa71MCqQ%2Ba1sz41I%2BuR%2B1qa%2BI0kW%2Bz8RNLWMaSMXC%2Fsbriad01HpcbhSK8eAYKYGZIX02c%2BHNbByVuZGv5UyOjezvOxOyzAaff5k1zKhBn%2BkC68xKt%2F6OKqsJF1CN3ips2jFUtF0xbK%2FD9NqeVy35rhL5zObMOgtZameDBi4skat5in8Gffbcgal2fbUy7vppStMbszwukE36hDgrWSOQmbpfA0tYMqJPWbz8A9xKk390%2FouI14%2B8%2BaCB7ZdqmzbSUlxMchZM9ZUVC0mTABDfwVw4O7WOLpeMpFS7oGCS%2F23btJefhRznXQEmNj081OM%2FC3b2zNxHRg542iSPpnYs7Ss5BMZnDdqFdLAHCnjVkHvrOSgRllue4YvFoQNp%2FVCgasxOLBLP2qNN28llxQewDX6NqpYygbgoXydp5yOu2NxvwvJqv6gxO0zoAX9Pj7czsekjJ7qkKPBqyMg2Y4%2BtrfIVkw%2F%2Fn%2Bs0YVLBfBeKL9o2ipseF4zSvEo6ddJtqO0EWPXDnGaUwzLmK0QY6mAEW2gAIVjI1zv4bgb84CR5Xlx8c6b333Ey3l497oHhn2x9Lv6iSIhYUJOjhxbWHJPkja%2F11mklLyUxGp50hVqARc0XCLGD4c7vgBH5MCxClujU%2BGKIPir99UiCdgyie0EK11S5MuzmwRNQaY0uh01B0VLRNe0B3LwVLtIvB%2FdZO6t1V21iTUCKMiVUBVXYSR%2BM1zMOEqwMy0g%3D%3D&Expires=1780656799)
#
# How the two runs compare conceptually
#
# The OLS code is a **fixed-time-point cross-sectional comparison** at 30, 60, and 90 days. Each day is analyzed separately, which makes interpretation clean but discards the full longitudinal structure. [ppl-ai-file-upload.s3.amazonaws](https://ppl-ai-file-upload.s3.amazonaws.com/web/direct-files/attachments/images/8778350/5786a2c1-9041-48be-9fe4-2deaf70c5440/image.jpg?AWSAccessKeyId=ASIA2F3EMEYEWTLAVILQ&Signature=aK5nq6ZEb4T3kiAT%2BRBkTTWnlZc%3D&x-amz-security-token=IQoJb3JpZ2luX2VjEKL%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEaCXVzLWVhc3QtMSJHMEUCIEoalQjTv4S8g%2FaeyE3SQC7q1AD4rgBLfV3ra3bwALZpAiEA2vodrZU2gI6KnB%2BrF%2FUE%2B0xEmMdVb%2ByBCUZbRgwt6rMq8wQIaxABGgw2OTk3NTMzMDk3MDUiDGmpTJBIa0WHaKBCMSrQBEDxFXOV0I7DbumDzwn4fHoIGFFzfl3Sy2jjK3bf83%2BSCm9sSmJV9EnNOkCHZZkmX6k8ROntK7ygX2MwAO3f%2FVMBOKEE1XFH2dAwI9Xb461CYjN0pWUf0l4s9gpcgXGOfNJxEqEDSr9F3YxTyeqrrRgQ2PCv1idf1zxx%2FS5sM7W4oVi1DWhomXYUIA2AeLklheDAzsalD%2Bo%2B3V9izecjVHCPk%2BddhuPV%2BT4QuQmpCJrjJYJE0wsLdIasr7NqTq7%2BnFojSBTsv3%2BRbQNa71MCqQ%2Ba1sz41I%2BuR%2B1qa%2BI0kW%2Bz8RNLWMaSMXC%2Fsbriad01HpcbhSK8eAYKYGZIX02c%2BHNbByVuZGv5UyOjezvOxOyzAaff5k1zKhBn%2BkC68xKt%2F6OKqsJF1CN3ips2jFUtF0xbK%2FD9NqeVy35rhL5zObMOgtZameDBi4skat5in8Gffbcgal2fbUy7vppStMbszwukE36hDgrWSOQmbpfA0tYMqJPWbz8A9xKk390%2FouI14%2B8%2BaCB7ZdqmzbSUlxMchZM9ZUVC0mTABDfwVw4O7WOLpeMpFS7oGCS%2F23btJefhRznXQEmNj081OM%2FC3b2zNxHRg542iSPpnYs7Ss5BMZnDdqFdLAHCnjVkHvrOSgRllue4YvFoQNp%2FVCgasxOLBLP2qNN28llxQewDX6NqpYygbgoXydp5yOu2NxvwvJqv6gxO0zoAX9Pj7czsekjJ7qkKPBqyMg2Y4%2BtrfIVkw%2F%2Fn%2Bs0YVLBfBeKL9o2ipseF4zSvEo6ddJtqO0EWPXDnGaUwzLmK0QY6mAEW2gAIVjI1zv4bgb84CR5Xlx8c6b333Ey3l497oHhn2x9Lv6iSIhYUJOjhxbWHJPkja%2F11mklLyUxGp50hVqARc0XCLGD4c7vgBH5MCxClujU%2BGKIPir99UiCdgyie0EK11S5MuzmwRNQaY0uh01B0VLRNe0B3LwVLtIvB%2FdZO6t1V21iTUCKMiVUBVXYSR%2BM1zMOEqwMy0g%3D%3D&Expires=1780656799)
#
# The mixed model is a **longitudinal trajectory model**. It uses all observed follow-up days at once, borrows information across time, and estimates a smooth path. That is more efficient, but harder to interpret coefficient-by-coefficient. [ppl-ai-file-upload.s3.amazonaws](https://ppl-ai-file-upload.s3.amazonaws.com/web/direct-files/attachments/images/8778350/5786a2c1-9041-48be-9fe4-2deaf70c5440/image.jpg?AWSAccessKeyId=ASIA2F3EMEYEWTLAVILQ&Signature=aK5nq6ZEb4T3kiAT%2BRBkTTWnlZc%3D&x-amz-security-token=IQoJb3JpZ2luX2VjEKL%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEaCXVzLWVhc3QtMSJHMEUCIEoalQjTv4S8g%2FaeyE3SQC7q1AD4rgBLfV3ra3bwALZpAiEA2vodrZU2gI6KnB%2BrF%2FUE%2B0xEmMdVb%2ByBCUZbRgwt6rMq8wQIaxABGgw2OTk3NTMzMDk3MDUiDGmpTJBIa0WHaKBCMSrQBEDxFXOV0I7DbumDzwn4fHoIGFFzfl3Sy2jjK3bf83%2BSCm9sSmJV9EnNOkCHZZkmX6k8ROntK7ygX2MwAO3f%2FVMBOKEE1XFH2dAwI9Xb461CYjN0pWUf0l4s9gpcgXGOfNJxEqEDSr9F3YxTyeqrrRgQ2PCv1idf1zxx%2FS5sM7W4oVi1DWhomXYUIA2AeLklheDAzsalD%2Bo%2B3V9izecjVHCPk%2BddhuPV%2BT4QuQmpCJrjJYJE0wsLdIasr7NqTq7%2BnFojSBTsv3%2BRbQNa71MCqQ%2Ba1sz41I%2BuR%2B1qa%2BI0kW%2Bz8RNLWMaSMXC%2Fsbriad01HpcbhSK8eAYKYGZIX02c%2BHNbByVuZGv5UyOjezvOxOyzAaff5k1zKhBn%2BkC68xKt%2F6OKqsJF1CN3ips2jFUtF0xbK%2FD9NqeVy35rhL5zObMOgtZameDBi4skat5in8Gffbcgal2fbUy7vppStMbszwukE36hDgrWSOQmbpfA0tYMqJPWbz8A9xKk390%2FouI14%2B8%2BaCB7ZdqmzbSUlxMchZM9ZUVC0mTABDfwVw4O7WOLpeMpFS7oGCS%2F23btJefhRznXQEmNj081OM%2FC3b2zNxHRg542iSPpnYs7Ss5BMZnDdqFdLAHCnjVkHvrOSgRllue4YvFoQNp%2FVCgasxOLBLP2qNN28llxQewDX6NqpYygbgoXydp5yOu2NxvwvJqv6gxO0zoAX9Pj7czsekjJ7qkKPBqyMg2Y4%2BtrfIVkw%2F%2Fn%2Bs0YVLBfBeKL9o2ipseF4zSvEo6ddJtqO0EWPXDnGaUwzLmK0QY6mAEW2gAIVjI1zv4bgb84CR5Xlx8c6b333Ey3l497oHhn2x9Lv6iSIhYUJOjhxbWHJPkja%2F11mklLyUxGp50hVqARc0XCLGD4c7vgBH5MCxClujU%2BGKIPir99UiCdgyie0EK11S5MuzmwRNQaY0uh01B0VLRNe0B3LwVLtIvB%2FdZO6t1V21iTUCKMiVUBVXYSR%2BM1zMOEqwMy0g%3D%3D&Expires=1780656799)
#
# What the table from OLS means
#
# Your OLS summary says, for example, that at day 90:
#
# - Personalized d30: adjusted weight loss = -6.698%.
# - Personalized d30-60: adjusted weight loss = -4.408%.
# - Personalized late: adjusted weight loss = -3.097%. [ppl-ai-file-upload.s3.amazonaws](https://ppl-ai-file-upload.s3.amazonaws.com/web/direct-files/attachments/images/8778350/5786a2c1-9041-48be-9fe4-2deaf70c5440/image.jpg?AWSAccessKeyId=ASIA2F3EMEYEWTLAVILQ&Signature=aK5nq6ZEb4T3kiAT%2BRBkTTWnlZc%3D&x-amz-security-token=IQoJb3JpZ2luX2VjEKL%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEaCXVzLWVhc3QtMSJHMEUCIEoalQjTv4S8g%2FaeyE3SQC7q1AD4rgBLfV3ra3bwALZpAiEA2vodrZU2gI6KnB%2BrF%2FUE%2B0xEmMdVb%2ByBCUZbRgwt6rMq8wQIaxABGgw2OTk3NTMzMDk3MDUiDGmpTJBIa0WHaKBCMSrQBEDxFXOV0I7DbumDzwn4fHoIGFFzfl3Sy2jjK3bf83%2BSCm9sSmJV9EnNOkCHZZkmX6k8ROntK7ygX2MwAO3f%2FVMBOKEE1XFH2dAwI9Xb461CYjN0pWUf0l4s9gpcgXGOfNJxEqEDSr9F3YxTyeqrrRgQ2PCv1idf1zxx%2FS5sM7W4oVi1DWhomXYUIA2AeLklheDAzsalD%2Bo%2B3V9izecjVHCPk%2BddhuPV%2BT4QuQmpCJrjJYJE0wsLdIasr7NqTq7%2BnFojSBTsv3%2BRbQNa71MCqQ%2Ba1sz41I%2BuR%2B1qa%2BI0kW%2Bz8RNLWMaSMXC%2Fsbriad01HpcbhSK8eAYKYGZIX02c%2BHNbByVuZGv5UyOjezvOxOyzAaff5k1zKhBn%2BkC68xKt%2F6OKqsJF1CN3ips2jFUtF0xbK%2FD9NqeVy35rhL5zObMOgtZameDBi4skat5in8Gffbcgal2fbUy7vppStMbszwukE36hDgrWSOQmbpfA0tYMqJPWbz8A9xKk390%2FouI14%2B8%2BaCB7ZdqmzbSUlxMchZM9ZUVC0mTABDfwVw4O7WOLpeMpFS7oGCS%2F23btJefhRznXQEmNj081OM%2FC3b2zNxHRg542iSPpnYs7Ss5BMZnDdqFdLAHCnjVkHvrOSgRllue4YvFoQNp%2FVCgasxOLBLP2qNN28llxQewDX6NqpYygbgoXydp5yOu2NxvwvJqv6gxO0zoAX9Pj7czsekjJ7qkKPBqyMg2Y4%2BtrfIVkw%2F%2Fn%2Bs0YVLBfBeKL9o2ipseF4zSvEo6ddJtqO0EWPXDnGaUwzLmK0QY6mAEW2gAIVjI1zv4bgb84CR5Xlx8c6b333Ey3l497oHhn2x9Lv6iSIhYUJOjhxbWHJPkja%2F11mklLyUxGp50hVqARc0XCLGD4c7vgBH5MCxClujU%2BGKIPir99UiCdgyie0EK11S5MuzmwRNQaY0uh01B0VLRNe0B3LwVLtIvB%2FdZO6t1V21iTUCKMiVUBVXYSR%2BM1zMOEqwMy0g%3D%3D&Expires=1780656799)
#
# That is directly interpretable as predicted percent loss at day 90 after adjusting to a common covariate profile. [ppl-ai-file-upload.s3.amazonaws](https://ppl-ai-file-upload.s3.amazonaws.com/web/direct-files/attachments/images/8778350/5786a2c1-9041-48be-9fe4-2deaf70c5440/image.jpg?AWSAccessKeyId=ASIA2F3EMEYEWTLAVILQ&Signature=aK5nq6ZEb4T3kiAT%2BRBkTTWnlZc%3D&x-amz-security-token=IQoJb3JpZ2luX2VjEKL%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEaCXVzLWVhc3QtMSJHMEUCIEoalQjTv4S8g%2FaeyE3SQC7q1AD4rgBLfV3ra3bwALZpAiEA2vodrZU2gI6KnB%2BrF%2FUE%2B0xEmMdVb%2ByBCUZbRgwt6rMq8wQIaxABGgw2OTk3NTMzMDk3MDUiDGmpTJBIa0WHaKBCMSrQBEDxFXOV0I7DbumDzwn4fHoIGFFzfl3Sy2jjK3bf83%2BSCm9sSmJV9EnNOkCHZZkmX6k8ROntK7ygX2MwAO3f%2FVMBOKEE1XFH2dAwI9Xb461CYjN0pWUf0l4s9gpcgXGOfNJxEqEDSr9F3YxTyeqrrRgQ2PCv1idf1zxx%2FS5sM7W4oVi1DWhomXYUIA2AeLklheDAzsalD%2Bo%2B3V9izecjVHCPk%2BddhuPV%2BT4QuQmpCJrjJYJE0wsLdIasr7NqTq7%2BnFojSBTsv3%2BRbQNa71MCqQ%2Ba1sz41I%2BuR%2B1qa%2BI0kW%2Bz8RNLWMaSMXC%2Fsbriad01HpcbhSK8eAYKYGZIX02c%2BHNbByVuZGv5UyOjezvOxOyzAaff5k1zKhBn%2BkC68xKt%2F6OKqsJF1CN3ips2jFUtF0xbK%2FD9NqeVy35rhL5zObMOgtZameDBi4skat5in8Gffbcgal2fbUy7vppStMbszwukE36hDgrWSOQmbpfA0tYMqJPWbz8A9xKk390%2FouI14%2B8%2BaCB7ZdqmzbSUlxMchZM9ZUVC0mTABDfwVw4O7WOLpeMpFS7oGCS%2F23btJefhRznXQEmNj081OM%2FC3b2zNxHRg542iSPpnYs7Ss5BMZnDdqFdLAHCnjVkHvrOSgRllue4YvFoQNp%2FVCgasxOLBLP2qNN28llxQewDX6NqpYygbgoXydp5yOu2NxvwvJqv6gxO0zoAX9Pj7czsekjJ7qkKPBqyMg2Y4%2BtrfIVkw%2F%2Fn%2Bs0YVLBfBeKL9o2ipseF4zSvEo6ddJtqO0EWPXDnGaUwzLmK0QY6mAEW2gAIVjI1zv4bgb84CR5Xlx8c6b333Ey3l497oHhn2x9Lv6iSIhYUJOjhxbWHJPkja%2F11mklLyUxGp50hVqARc0XCLGD4c7vgBH5MCxClujU%2BGKIPir99UiCdgyie0EK11S5MuzmwRNQaY0uh01B0VLRNe0B3LwVLtIvB%2FdZO6t1V21iTUCKMiVUBVXYSR%2BM1zMOEqwMy0g%3D%3D&Expires=1780656799)
#
# What the mixed model table means instead
#
# The mixed model coefficients are not day-specific outcomes. They are parameters of the smooth trajectory function, so the comparison comes from **predicted values at chosen days**, not from the coefficients themselves. [ppl-ai-file-upload.s3.amazonaws](https://ppl-ai-file-upload.s3.amazonaws.com/web/direct-files/attachments/images/8778350/5786a2c1-9041-48be-9fe4-2deaf70c5440/image.jpg?AWSAccessKeyId=ASIA2F3EMEYEWTLAVILQ&Signature=aK5nq6ZEb4T3kiAT%2BRBkTTWnlZc%3D&x-amz-security-token=IQoJb3JpZ2luX2VjEKL%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEaCXVzLWVhc3QtMSJHMEUCIEoalQjTv4S8g%2FaeyE3SQC7q1AD4rgBLfV3ra3bwALZpAiEA2vodrZU2gI6KnB%2BrF%2FUE%2B0xEmMdVb%2ByBCUZbRgwt6rMq8wQIaxABGgw2OTk3NTMzMDk3MDUiDGmpTJBIa0WHaKBCMSrQBEDxFXOV0I7DbumDzwn4fHoIGFFzfl3Sy2jjK3bf83%2BSCm9sSmJV9EnNOkCHZZkmX6k8ROntK7ygX2MwAO3f%2FVMBOKEE1XFH2dAwI9Xb461CYjN0pWUf0l4s9gpcgXGOfNJxEqEDSr9F3YxTyeqrrRgQ2PCv1idf1zxx%2FS5sM7W4oVi1DWhomXYUIA2AeLklheDAzsalD%2Bo%2B3V9izecjVHCPk%2BddhuPV%2BT4QuQmpCJrjJYJE0wsLdIasr7NqTq7%2BnFojSBTsv3%2BRbQNa71MCqQ%2Ba1sz41I%2BuR%2B1qa%2BI0kW%2Bz8RNLWMaSMXC%2Fsbriad01HpcbhSK8eAYKYGZIX02c%2BHNbByVuZGv5UyOjezvOxOyzAaff5k1zKhBn%2BkC68xKt%2F6OKqsJF1CN3ips2jFUtF0xbK%2FD9NqeVy35rhL5zObMOgtZameDBi4skat5in8Gffbcgal2fbUy7vppStMbszwukE36hDgrWSOQmbpfA0tYMqJPWbz8A9xKk390%2FouI14%2B8%2BaCB7ZdqmzbSUlxMchZM9ZUVC0mTABDfwVw4O7WOLpeMpFS7oGCS%2F23btJefhRznXQEmNj081OM%2FC3b2zNxHRg542iSPpnYs7Ss5BMZnDdqFdLAHCnjVkHvrOSgRllue4YvFoQNp%2FVCgasxOLBLP2qNN28llxQewDX6NqpYygbgoXydp5yOu2NxvwvJqv6gxO0zoAX9Pj7czsekjJ7qkKPBqyMg2Y4%2BtrfIVkw%2F%2Fn%2Bs0YVLBfBeKL9o2ipseF4zSvEo6ddJtqO0EWPXDnGaUwzLmK0QY6mAEW2gAIVjI1zv4bgb84CR5Xlx8c6b333Ey3l497oHhn2x9Lv6iSIhYUJOjhxbWHJPkja%2F11mklLyUxGp50hVqARc0XCLGD4c7vgBH5MCxClujU%2BGKIPir99UiCdgyie0EK11S5MuzmwRNQaY0uh01B0VLRNe0B3LwVLtIvB%2FdZO6t1V21iTUCKMiVUBVXYSR%2BM1zMOEqwMy0g%3D%3D&Expires=1780656799)
#
# So if you want to compare the two approaches fairly, compare:
#
# - OLS adjusted predicted **% weight loss** at day 30/60/90.
# - Mixed-model predicted **weight change from day 0** at the same days, converted to kg or percent. [ppl-ai-file-upload.s3.amazonaws](https://ppl-ai-file-upload.s3.amazonaws.com/web/direct-files/attachments/images/8778350/5786a2c1-9041-48be-9fe4-2deaf70c5440/image.jpg?AWSAccessKeyId=ASIA2F3EMEYEWTLAVILQ&Signature=aK5nq6ZEb4T3kiAT%2BRBkTTWnlZc%3D&x-amz-security-token=IQoJb3JpZ2luX2VjEKL%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEaCXVzLWVhc3QtMSJHMEUCIEoalQjTv4S8g%2FaeyE3SQC7q1AD4rgBLfV3ra3bwALZpAiEA2vodrZU2gI6KnB%2BrF%2FUE%2B0xEmMdVb%2ByBCUZbRgwt6rMq8wQIaxABGgw2OTk3NTMzMDk3MDUiDGmpTJBIa0WHaKBCMSrQBEDxFXOV0I7DbumDzwn4fHoIGFFzfl3Sy2jjK3bf83%2BSCm9sSmJV9EnNOkCHZZkmX6k8ROntK7ygX2MwAO3f%2FVMBOKEE1XFH2dAwI9Xb461CYjN0pWUf0l4s9gpcgXGOfNJxEqEDSr9F3YxTyeqrrRgQ2PCv1idf1zxx%2FS5sM7W4oVi1DWhomXYUIA2AeLklheDAzsalD%2Bo%2B3V9izecjVHCPk%2BddhuPV%2BT4QuQmpCJrjJYJE0wsLdIasr7NqTq7%2BnFojSBTsv3%2BRbQNa71MCqQ%2Ba1sz41I%2BuR%2B1qa%2BI0kW%2Bz8RNLWMaSMXC%2Fsbriad01HpcbhSK8eAYKYGZIX02c%2BHNbByVuZGv5UyOjezvOxOyzAaff5k1zKhBn%2BkC68xKt%2F6OKqsJF1CN3ips2jFUtF0xbK%2FD9NqeVy35rhL5zObMOgtZameDBi4skat5in8Gffbcgal2fbUy7vppStMbszwukE36hDgrWSOQmbpfA0tYMqJPWbz8A9xKk390%2FouI14%2B8%2BaCB7ZdqmzbSUlxMchZM9ZUVC0mTABDfwVw4O7WOLpeMpFS7oGCS%2F23btJefhRznXQEmNj081OM%2FC3b2zNxHRg542iSPpnYs7Ss5BMZnDdqFdLAHCnjVkHvrOSgRllue4YvFoQNp%2FVCgasxOLBLP2qNN28llxQewDX6NqpYygbgoXydp5yOu2NxvwvJqv6gxO0zoAX9Pj7czsekjJ7qkKPBqyMg2Y4%2BtrfIVkw%2F%2Fn%2Bs0YVLBfBeKL9o2ipseF4zSvEo6ddJtqO0EWPXDnGaUwzLmK0QY6mAEW2gAIVjI1zv4bgb84CR5Xlx8c6b333Ey3l497oHhn2x9Lv6iSIhYUJOjhxbWHJPkja%2F11mklLyUxGp50hVqARc0XCLGD4c7vgBH5MCxClujU%2BGKIPir99UiCdgyie0EK11S5MuzmwRNQaY0uh01B0VLRNe0B3LwVLtIvB%2FdZO6t1V21iTUCKMiVUBVXYSR%2BM1zMOEqwMy0g%3D%3D&Expires=1780656799)
#
# Best interpretation for your project
#
# For your thesis, the mixed model is better if your goal is to describe a continuous post-personalization trajectory. The OLS approach is better if your goal is to provide clear, fixed-time-point summaries. [ppl-ai-file-upload.s3.amazonaws](https://ppl-ai-file-upload.s3.amazonaws.com/web/direct-files/attachments/images/8778350/5786a2c1-9041-48be-9fe4-2deaf70c5440/image.jpg?AWSAccessKeyId=ASIA2F3EMEYEWTLAVILQ&Signature=aK5nq6ZEb4T3kiAT%2BRBkTTWnlZc%3D&x-amz-security-token=IQoJb3JpZ2luX2VjEKL%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEaCXVzLWVhc3QtMSJHMEUCIEoalQjTv4S8g%2FaeyE3SQC7q1AD4rgBLfV3ra3bwALZpAiEA2vodrZU2gI6KnB%2BrF%2FUE%2B0xEmMdVb%2ByBCUZbRgwt6rMq8wQIaxABGgw2OTk3NTMzMDk3MDUiDGmpTJBIa0WHaKBCMSrQBEDxFXOV0I7DbumDzwn4fHoIGFFzfl3Sy2jjK3bf83%2BSCm9sSmJV9EnNOkCHZZkmX6k8ROntK7ygX2MwAO3f%2FVMBOKEE1XFH2dAwI9Xb461CYjN0pWUf0l4s9gpcgXGOfNJxEqEDSr9F3YxTyeqrrRgQ2PCv1idf1zxx%2FS5sM7W4oVi1DWhomXYUIA2AeLklheDAzsalD%2Bo%2B3V9izecjVHCPk%2BddhuPV%2BT4QuQmpCJrjJYJE0wsLdIasr7NqTq7%2BnFojSBTsv3%2BRbQNa71MCqQ%2Ba1sz41I%2BuR%2B1qa%2BI0kW%2Bz8RNLWMaSMXC%2Fsbriad01HpcbhSK8eAYKYGZIX02c%2BHNbByVuZGv5UyOjezvOxOyzAaff5k1zKhBn%2BkC68xKt%2F6OKqsJF1CN3ips2jFUtF0xbK%2FD9NqeVy35rhL5zObMOgtZameDBi4skat5in8Gffbcgal2fbUy7vppStMbszwukE36hDgrWSOQmbpfA0tYMqJPWbz8A9xKk390%2FouI14%2B8%2BaCB7ZdqmzbSUlxMchZM9ZUVC0mTABDfwVw4O7WOLpeMpFS7oGCS%2F23btJefhRznXQEmNj081OM%2FC3b2zNxHRg542iSPpnYs7Ss5BMZnDdqFdLAHCnjVkHvrOSgRllue4YvFoQNp%2FVCgasxOLBLP2qNN28llxQewDX6NqpYygbgoXydp5yOu2NxvwvJqv6gxO0zoAX9Pj7czsekjJ7qkKPBqyMg2Y4%2BtrfIVkw%2F%2Fn%2Bs0YVLBfBeKL9o2ipseF4zSvEo6ddJtqO0EWPXDnGaUwzLmK0QY6mAEW2gAIVjI1zv4bgb84CR5Xlx8c6b333Ey3l497oHhn2x9Lv6iSIhYUJOjhxbWHJPkja%2F11mklLyUxGp50hVqARc0XCLGD4c7vgBH5MCxClujU%2BGKIPir99UiCdgyie0EK11S5MuzmwRNQaY0uh01B0VLRNe0B3LwVLtIvB%2FdZO6t1V21iTUCKMiVUBVXYSR%2BM1zMOEqwMy0g%3D%3D&Expires=1780656799)
#
# They are not contradictory. They answer slightly different questions, and the mixed model is closer to a longitudinal causal/trajectory framework, while the OLS version is a clean descriptive-adjusted comparison at selected days. [ppl-ai-file-upload.s3.amazonaws](https://ppl-ai-file-upload.s3.amazonaws.com/web/direct-files/attachments/images/8778350/5786a2c1-9041-48be-9fe4-2deaf70c5440/image.jpg?AWSAccessKeyId=ASIA2F3EMEYEWTLAVILQ&Signature=aK5nq6ZEb4T3kiAT%2BRBkTTWnlZc%3D&x-amz-security-token=IQoJb3JpZ2luX2VjEKL%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEaCXVzLWVhc3QtMSJHMEUCIEoalQjTv4S8g%2FaeyE3SQC7q1AD4rgBLfV3ra3bwALZpAiEA2vodrZU2gI6KnB%2BrF%2FUE%2B0xEmMdVb%2ByBCUZbRgwt6rMq8wQIaxABGgw2OTk3NTMzMDk3MDUiDGmpTJBIa0WHaKBCMSrQBEDxFXOV0I7DbumDzwn4fHoIGFFzfl3Sy2jjK3bf83%2BSCm9sSmJV9EnNOkCHZZkmX6k8ROntK7ygX2MwAO3f%2FVMBOKEE1XFH2dAwI9Xb461CYjN0pWUf0l4s9gpcgXGOfNJxEqEDSr9F3YxTyeqrrRgQ2PCv1idf1zxx%2FS5sM7W4oVi1DWhomXYUIA2AeLklheDAzsalD%2Bo%2B3V9izecjVHCPk%2BddhuPV%2BT4QuQmpCJrjJYJE0wsLdIasr7NqTq7%2BnFojSBTsv3%2BRbQNa71MCqQ%2Ba1sz41I%2BuR%2B1qa%2BI0kW%2Bz8RNLWMaSMXC%2Fsbriad01HpcbhSK8eAYKYGZIX02c%2BHNbByVuZGv5UyOjezvOxOyzAaff5k1zKhBn%2BkC68xKt%2F6OKqsJF1CN3ips2jFUtF0xbK%2FD9NqeVy35rhL5zObMOgtZameDBi4skat5in8Gffbcgal2fbUy7vppStMbszwukE36hDgrWSOQmbpfA0tYMqJPWbz8A9xKk390%2FouI14%2B8%2BaCB7ZdqmzbSUlxMchZM9ZUVC0mTABDfwVw4O7WOLpeMpFS7oGCS%2F23btJefhRznXQEmNj081OM%2FC3b2zNxHRg542iSPpnYs7Ss5BMZnDdqFdLAHCnjVkHvrOSgRllue4YvFoQNp%2FVCgasxOLBLP2qNN28llxQewDX6NqpYygbgoXydp5yOu2NxvwvJqv6gxO0zoAX9Pj7czsekjJ7qkKPBqyMg2Y4%2BtrfIVkw%2F%2Fn%2Bs0YVLBfBeKL9o2ipseF4zSvEo6ddJtqO0EWPXDnGaUwzLmK0QY6mAEW2gAIVjI1zv4bgb84CR5Xlx8c6b333Ey3l497oHhn2x9Lv6iSIhYUJOjhxbWHJPkja%2F11mklLyUxGp50hVqARc0XCLGD4c7vgBH5MCxClujU%2BGKIPir99UiCdgyie0EK11S5MuzmwRNQaY0uh01B0VLRNe0B3LwVLtIvB%2FdZO6t1V21iTUCKMiVUBVXYSR%2BM1zMOEqwMy0g%3D%3D&Expires=1780656799)
#
#  One caution
#
# Your OLS model uses `wl_%_at_genomics_results` as a covariate, but that should be checked carefully for consistency with the mixed model’s `wl_pct_at_genomics_results` naming and meaning. If those are not exactly the same variable, the two analyses may not be adjusting on the same scale. [ppl-ai-file-upload.s3.amazonaws](https://ppl-ai-file-upload.s3.amazonaws.com/web/direct-files/attachments/images/8778350/5786a2c1-9041-48be-9fe4-2deaf70c5440/image.jpg?AWSAccessKeyId=ASIA2F3EMEYEWTLAVILQ&Signature=aK5nq6ZEb4T3kiAT%2BRBkTTWnlZc%3D&x-amz-security-token=IQoJb3JpZ2luX2VjEKL%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEaCXVzLWVhc3QtMSJHMEUCIEoalQjTv4S8g%2FaeyE3SQC7q1AD4rgBLfV3ra3bwALZpAiEA2vodrZU2gI6KnB%2BrF%2FUE%2B0xEmMdVb%2ByBCUZbRgwt6rMq8wQIaxABGgw2OTk3NTMzMDk3MDUiDGmpTJBIa0WHaKBCMSrQBEDxFXOV0I7DbumDzwn4fHoIGFFzfl3Sy2jjK3bf83%2BSCm9sSmJV9EnNOkCHZZkmX6k8ROntK7ygX2MwAO3f%2FVMBOKEE1XFH2dAwI9Xb461CYjN0pWUf0l4s9gpcgXGOfNJxEqEDSr9F3YxTyeqrrRgQ2PCv1idf1zxx%2FS5sM7W4oVi1DWhomXYUIA2AeLklheDAzsalD%2Bo%2B3V9izecjVHCPk%2BddhuPV%2BT4QuQmpCJrjJYJE0wsLdIasr7NqTq7%2BnFojSBTsv3%2BRbQNa71MCqQ%2Ba1sz41I%2BuR%2B1qa%2BI0kW%2Bz8RNLWMaSMXC%2Fsbriad01HpcbhSK8eAYKYGZIX02c%2BHNbByVuZGv5UyOjezvOxOyzAaff5k1zKhBn%2BkC68xKt%2F6OKqsJF1CN3ips2jFUtF0xbK%2FD9NqeVy35rhL5zObMOgtZameDBi4skat5in8Gffbcgal2fbUy7vppStMbszwukE36hDgrWSOQmbpfA0tYMqJPWbz8A9xKk390%2FouI14%2B8%2BaCB7ZdqmzbSUlxMchZM9ZUVC0mTABDfwVw4O7WOLpeMpFS7oGCS%2F23btJefhRznXQEmNj081OM%2FC3b2zNxHRg542iSPpnYs7Ss5BMZnDdqFdLAHCnjVkHvrOSgRllue4YvFoQNp%2FVCgasxOLBLP2qNN28llxQewDX6NqpYygbgoXydp5yOu2NxvwvJqv6gxO0zoAX9Pj7czsekjJ7qkKPBqyMg2Y4%2BtrfIVkw%2F%2Fn%2Bs0YVLBfBeKL9o2ipseF4zSvEo6ddJtqO0EWPXDnGaUwzLmK0QY6mAEW2gAIVjI1zv4bgb84CR5Xlx8c6b333Ey3l497oHhn2x9Lv6iSIhYUJOjhxbWHJPkja%2F11mklLyUxGp50hVqARc0XCLGD4c7vgBH5MCxClujU%2BGKIPir99UiCdgyie0EK11S5MuzmwRNQaY0uh01B0VLRNe0B3LwVLtIvB%2FdZO6t1V21iTUCKMiVUBVXYSR%2BM1zMOEqwMy0g%3D%3D&Expires=1780656799)
#
# If you want, the next step is to align the two methods mathematically, so you can compare them on the exact same estimand: predicted **change from day 0** at 30, 60, and 90 days.

# %% [markdown]
# Difference between LMM and regression post-personalization trajectory analyses:

# %% [markdown]
# ## PAST ------------------------------------------------------------------------------

# %% [markdown]
# ### March 2026

# %% [markdown]
# #### 3Mar26

# %% [markdown]
# observation: first meas to genomics results days range: -873 - 1200 - ie within the same

# %% [markdown]
# #### 2Mar26

# %% [markdown]
# observation: in db2_genomics_in when identifying genomics data-record date relationships, some (240) patients have 'genomics after record' but they have only a single record. How is this possible? Most likely explanation, supported by spot checks although not formally tested, is the following:
# - in the tte table, the final_date is NOT the same as the medical_record_closing_date, but it's the date of the last measurement
# - this means that a record can be open even after the last measurement,
# - because either the patient drops out or disappears, or simply data collection stops or data is lost.
# - in these patients (this is what spot checks show), they start intervention, order genomics, their results arrive and the date is recorded,
# - BUT their last measurement is recorded before the arrival of their genomics test result, because of dropout or data loss.
# - There are even cases where data is collected for hundreds of days, nearly two years, and the genomics result arrives in the last few months or weeks, and data collection stops before that.
#
# Data from these patients can be useful in genetics-to-obesity associations, and to some level, even genetics to weight loss.
#
# Actually, great idea - we can study the effects of genetics on weight loss WITHOUT PERSONALIZATION on records that at a later point, get genomics, but they also have non-personalized records!!

# %% [markdown]
# observation: other patients have genomics BEFORE record tag in their first, sometimes only, record (n 119 first, 97 first and only). How can this be possible?
#
# According to spot checks, these patients had a record opened, with no measurements for a period of some days/weeks/months, maybe getting a genomics result in that time. This reinforces the observation that medical record open/close dates do not coincide with measurement dates - which makes sense as one is done by patients and the other by doctors.
